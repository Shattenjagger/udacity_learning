# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6465 0.1285 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6418 0.0594 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4996 0.0594 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6234 0.0589 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5000 0.0579 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5101 0.0589 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5485 0.0580 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5566 0.0614 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4522 0.0598 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4648 0.0618 sec/batch
# Nearest to can: mercilessly, intolerable, reads, gilligan, harman, sheets, globus, morales,
# Nearest to state: hammond, gunther, euthanasia, doubted, painstaking, beazley, muskie, rhino,
# Nearest to eight: compounding, alright, halt, nelly, english, rowdy, over, jila,
# Nearest to five: spacecrafts, prequels, infrastructural, battles, spectacles, abt, pig, founders,
# Nearest to s: routinely, kanno, radiocommunication, indo, topeka, talked, follicles, pursuit,
# Nearest to be: macroeconomics, maccabean, bacteriophage, elected, postwar, banteng, literacy, osler,
# Nearest to not: gotcha, matthau, permaculture, netting, porters, bcc, rearranging, howland,
# Nearest to but: exclaiming, kang, anoints, patently, assumption, verrocchio, shaking, blurring,
# Nearest to resources: leda, clearwater, architectural, vitoria, inquisitions, amg, degli, muzio,
# Nearest to event: monopolize, kambojas, sidestep, tones, pasteurization, experiences, normalization, dioscorus,
# Nearest to operating: chromodynamics, viking, reform, taney, subcover, logarithmic, westeros, blantyre,
# Nearest to institute: planets, ming, bergen, fright, horizon, behalf, abstraction, hydroxybutyrate,
# Nearest to rise: unaccountable, implausible, lanfranc, target, wilkinson, knocking, typologically, calibrated,
# Nearest to frac: dock, pillow, lipolysis, kashi, craft, semester, stratospheric, finale,
# Nearest to road: melanoleuca, gasses, tang, sausage, uffizi, recessive, eidos, etna,
# Nearest to lived: shih, assets, send, hooker, relieves, jurist, modulated, iy,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4640 0.0663 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3930 0.0654 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3319 0.0633 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2698 0.0644 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1667 0.0641 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2063 0.0659 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0984 0.0655 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0771 0.0656 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0030 0.0661 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9804 0.0651 sec/batch
# Nearest to can: mercilessly, reads, recorded, sheets, generic, exception, instance, intolerable,
# Nearest to state: doubted, end, hammond, land, but, part, tension, euthanasia,
# Nearest to eight: english, compounding, halt, over, nelly, undecidable, alright, franchise,
# Nearest to five: battles, founders, chatham, prequels, concerns, infrastructural, starred, dia,
# Nearest to s: routinely, counterparts, talked, pursuit, indo, nd, title, kanno,
# Nearest to be: however, elected, used, more, macroeconomics, banteng, literacy, need,
# Nearest to not: during, men, permaculture, matthau, honest, assist, rearranging, gotcha,
# Nearest to but: assumption, leads, couples, buildings, exclaiming, various, anoints, shaking,
# Nearest to resources: vitoria, being, architectural, errors, leda, germanic, degli, obviously,
# Nearest to event: kambojas, tones, compiled, normalization, experiences, counterparts, sidestep, employed,
# Nearest to operating: reform, martin, subcover, over, games, ticino, chromodynamics, logarithmic,
# Nearest to institute: planets, behalf, ming, abstraction, bergen, bachelor, commoners, perform,
# Nearest to rise: unaccountable, implausible, target, lanfranc, wilkinson, knocking, poll, switzerland,
# Nearest to frac: dock, craft, correct, lipolysis, pillow, culture, semester, metastasis,
# Nearest to road: gasses, sausage, tang, shapes, melanoleuca, confided, hue, obsolescence,
# Nearest to lived: send, assets, huge, shih, iy, total, relieves, research,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9538 0.0668 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9035 0.0664 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9002 0.0646 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8613 0.0648 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8106 0.0678 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8168 0.0644 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8096 0.0663 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8049 0.0667 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8019 0.0667 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7605 0.0660 sec/batch
# Nearest to can: reads, sheets, mercilessly, generic, organisational, instance, exception, intolerable,
# Nearest to state: hammond, doubted, land, gunther, euthanasia, end, levy, squaring,
# Nearest to eight: three, english, halt, compounding, nelly, violinist, over, alright,
# Nearest to five: infrastructural, three, prequels, starred, battles, one, founders, chatham,
# Nearest to s: talked, routinely, nd, indo, counterparts, paved, dating, pursuit,
# Nearest to be: used, however, postwar, literacy, elected, more, macroeconomics, storylines,
# Nearest to not: gotcha, honest, permaculture, denial, matthau, howland, assist, dogmas,
# Nearest to but: assumption, exclaiming, couples, buildings, anoints, leads, shaking, launch,
# Nearest to resources: vitoria, errors, architectural, leda, being, germanic, obviously, allegations,
# Nearest to event: experiences, tones, kambojas, sidestep, compiled, normalization, counterparts, monopolize,
# Nearest to operating: chromodynamics, reform, martin, subcover, doubly, games, logarithmic, faces,
# Nearest to institute: planets, ming, bergen, behalf, libre, abstraction, horizon, grows,
# Nearest to rise: unaccountable, poll, implausible, target, lanfranc, violent, wilkinson, knocking,
# Nearest to frac: correct, dock, craft, lipolysis, semester, romanization, metastasis, integral,
# Nearest to road: tang, gasses, melanoleuca, sausage, uffizi, obsolescence, confided, hue,
# Nearest to lived: assets, send, shih, hooker, iy, crater, jehovah, relieves,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7878 0.0683 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7549 0.0655 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7247 0.0660 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7180 0.0676 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7252 0.0655 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7041 0.0664 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6980 0.0680 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7181 0.0657 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6888 0.0662 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6794 0.0677 sec/batch
# Nearest to can: reads, generic, sheets, instance, quantities, organisational, mercilessly, commentators,
# Nearest to state: hammond, land, gunther, enriching, doubted, end, euthanasia, cura,
# Nearest to eight: three, english, american, six, five, violinist, nelly, halt,
# Nearest to five: three, one, composer, six, eight, infrastructural, prequels, benno,
# Nearest to s: nd, talked, indo, routinely, counterparts, paved, falkland, believing,
# Nearest to be: however, used, more, macroeconomics, postwar, literacy, storylines, banteng,
# Nearest to not: gotcha, honest, permaculture, dogmas, matthau, porters, installing, howland,
# Nearest to but: exclaiming, assumption, anoints, buildings, patently, couples, kang, actions,
# Nearest to resources: vitoria, leda, errors, architectural, clearwater, grams, stanislavsky, inquisitions,
# Nearest to event: kambojas, monopolize, tones, experiences, sidestep, compiled, normalization, pasteurization,
# Nearest to operating: chromodynamics, games, blantyre, reform, subcover, doubly, logarithmic, bowlers,
# Nearest to institute: planets, bergen, ming, libre, behalf, fright, abstraction, sami,
# Nearest to rise: unaccountable, poll, calibrated, implausible, lanfranc, knocking, target, hara,
# Nearest to frac: correct, metastasis, integral, n, lipolysis, romanization, pillow, craft,
# Nearest to road: tang, gasses, uffizi, sausage, confided, hue, melanoleuca, creep,
# Nearest to lived: shih, crater, hooker, trillions, send, scrooge, iy, assets,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6756 0.0659 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6812 0.0658 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6375 0.0685 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6516 0.0645 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6252 0.0664 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6553 0.0670 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6071 0.0504 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5679 0.0657 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5234 0.0679 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4818 0.0649 sec/batch
# Nearest to can: generic, quantities, instance, sheets, molecules, value, organisational, assumption,
# Nearest to state: hammond, land, enriching, gunther, cura, doubted, painstaking, euthanasia,
# Nearest to eight: three, violinist, english, six, american, nelly, five, halt,
# Nearest to five: three, composer, six, one, eight, infrastructural, artist, four,
# Nearest to s: talked, nd, indo, kanno, counterparts, routinely, veterans, antonin,
# Nearest to be: used, however, values, more, is, need, macroeconomics, banteng,
# Nearest to not: honest, gotcha, dogmas, porters, denial, permaculture, rearranging, matthau,
# Nearest to but: exclaiming, assumption, patently, anoints, leads, actions, couples, buildings,
# Nearest to resources: errors, architectural, leda, vitoria, grams, clearwater, stanislavsky, inquisitions,
# Nearest to event: monopolize, sidestep, kambojas, experiences, tones, compiled, pasteurization, normalization,
# Nearest to operating: chromodynamics, blantyre, games, bowlers, doubly, forgiving, susie, processors,
# Nearest to institute: planets, libre, bergen, ipod, dismemberment, ming, fright, bachelor,
# Nearest to rise: unaccountable, poll, calibrated, implausible, hara, lanfranc, target, wilkinson,
# Nearest to frac: n, correct, integral, metastasis, pillow, lipolysis, romanization, craft,
# Nearest to road: gasses, uffizi, tang, sausage, confided, eidos, hue, melanoleuca,
# Nearest to lived: shih, crater, trillions, empathic, chalmers, relieves, send, ausw,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5063 0.0664 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4732 0.0691 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4644 0.0616 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5375 0.0685 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4980 0.0628 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4825 0.0698 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4508 0.0626 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3972 0.0647 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4643 0.0664 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4364 0.0676 sec/batch
# Nearest to can: generic, quantities, instance, cartesian, molecules, describing, sheets, reads,
# Nearest to state: land, hammond, gunther, enriching, doubted, cura, euthanasia, painstaking,
# Nearest to eight: three, violinist, nelly, six, halt, english, american, five,
# Nearest to five: three, six, infrastructural, composer, one, prequels, benno, four,
# Nearest to s: nd, talked, kanno, counterparts, indo, southerly, veterans, title,
# Nearest to be: used, however, values, need, more, it, is, manipulate,
# Nearest to not: honest, gotcha, dogmas, rearranging, statements, also, sacrificial, provoke,
# Nearest to but: exclaiming, patently, assumption, leads, anoints, actions, buildings, undirected,
# Nearest to resources: errors, architectural, grams, optimizations, vitoria, leda, amg, stanislavsky,
# Nearest to event: sidestep, monopolize, experiences, kambojas, pasteurization, tones, compiled, overbeck,
# Nearest to operating: chromodynamics, blantyre, games, software, processors, bowlers, creations, digital,
# Nearest to institute: libre, dismemberment, planets, bergen, bachelor, ipod, fright, ming,
# Nearest to rise: calibrated, poll, unaccountable, target, zidane, lanfranc, hara, nico,
# Nearest to frac: n, integral, correct, z, metastasis, vector, calculate, lipolysis,
# Nearest to road: uffizi, eidos, hue, sausage, bermuda, gasses, goatskin, tang,
# Nearest to lived: shih, trillions, chalmers, meun, crater, empathic, hooker, send,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4254 0.0680 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4013 0.0652 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4397 0.0669 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4085 0.0660 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4621 0.0665 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4476 0.0661 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3745 0.0649 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3826 0.0664 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4130 0.0659 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4030 0.0659 sec/batch
# Nearest to can: generic, quantities, cartesian, describing, instance, value, assumption, globus,
# Nearest to state: land, painstaking, gunther, hammond, euthanasia, enforceable, cura, cheshire,
# Nearest to eight: three, violinist, nelly, six, five, halt, american, english,
# Nearest to five: three, one, six, four, infrastructural, eight, composer, prequels,
# Nearest to s: nd, talked, title, kanno, counterparts, veterans, surgeries, remixes,
# Nearest to be: used, however, values, need, more, it, macroeconomics, manipulate,
# Nearest to not: honest, statements, gotcha, dogmas, provoke, debate, denial, frauds,
# Nearest to but: exclaiming, assumption, leads, patently, actions, anoints, immediate, segmental,
# Nearest to resources: grams, architectural, errors, amg, stanislavsky, warlordism, vitoria, optimizations,
# Nearest to event: sidestep, experiences, monopolize, kambojas, pasteurization, counterparts, arxiv, tones,
# Nearest to operating: chromodynamics, software, blantyre, games, processors, kernel, digital, bowlers,
# Nearest to institute: libre, dismemberment, bachelor, bergen, ipod, planets, fright, ming,
# Nearest to rise: calibrated, zidane, target, unaccountable, poll, hara, lanfranc, shortfall,
# Nearest to frac: n, integral, z, correct, metastasis, vector, calculate, cdots,
# Nearest to road: uffizi, eidos, bermuda, hue, sausage, reposition, goatskin, uncontrollably,
# Nearest to lived: chalmers, meun, shih, trillions, empathic, hooker, crater, ausw,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3881 0.0673 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3735 0.0671 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3354 0.0663 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3595 0.0664 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3842 0.0655 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3624 0.0674 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4035 0.0638 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3635 0.0662 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3025 0.0667 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3417 0.0669 sec/batch
# Nearest to can: generic, globus, quantities, cartesian, desirable, instance, describing, organisational,
# Nearest to state: corrupt, land, enforceable, hammond, gunther, painstaking, cura, among,
# Nearest to eight: three, six, violinist, five, halt, nelly, four, one,
# Nearest to five: three, one, six, four, eight, infrastructural, zero, straining,
# Nearest to s: nd, talked, kanno, veterans, title, antonin, southerly, surgeries,
# Nearest to be: used, however, it, values, need, more, mitosis, utilised,
# Nearest to not: honest, debate, gotcha, provoke, dogmas, statements, denial, hold,
# Nearest to but: exclaiming, assumption, leads, patently, anoints, segmental, actions, immediate,
# Nearest to resources: grams, amg, biodiversity, smelting, architectural, errors, conseil, stanislavsky,
# Nearest to event: sidestep, experiences, monopolize, kambojas, pasteurization, arxiv, counterparts, overbeck,
# Nearest to operating: software, blantyre, chromodynamics, processors, kernel, compatibles, scans, bowlers,
# Nearest to institute: libre, bachelor, dismemberment, ipod, bergen, fright, ming, engineering,
# Nearest to rise: calibrated, target, zidane, unaccountable, poll, pnh, follicles, hara,
# Nearest to frac: n, z, integral, sqrt, cdots, metastasis, calculate, cdot,
# Nearest to road: uffizi, eidos, goatskin, reposition, obsolescence, uncontrollably, scanty, hue,
# Nearest to lived: chalmers, meun, shih, formalist, ausw, trillions, empathic, crater,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3308 0.0678 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3028 0.0666 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3692 0.0663 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3858 0.0657 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3630 0.0655 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2867 0.0670 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2826 0.0660 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3341 0.0663 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2375 0.0676 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2766 0.0671 sec/batch
# Nearest to can: generic, quantities, describing, cartesian, desirable, globus, value, instance,
# Nearest to state: enforceable, corrupt, land, gunther, hammond, cura, determination, cheshire,
# Nearest to eight: three, violinist, six, five, one, four, nelly, english,
# Nearest to five: one, three, six, four, eight, zero, composer, infrastructural,
# Nearest to s: nd, talked, surgeries, antonin, kanno, veterans, goofy, butt,
# Nearest to be: however, it, used, mitosis, values, need, follows, bacteriophage,
# Nearest to not: honest, gotcha, provoke, debate, assist, desired, statements, porters,
# Nearest to but: exclaiming, leads, segmental, anoints, immediate, assumption, mps, patently,
# Nearest to resources: biodiversity, smelting, arable, amg, conseil, architectural, errors, stanislavsky,
# Nearest to event: sidestep, experiences, kambojas, monopolize, pasteurization, arxiv, clayton, spot,
# Nearest to operating: kernel, software, processors, chromodynamics, implementations, blantyre, compatibles, architectures,
# Nearest to institute: bachelor, libre, dismemberment, engineering, fright, bergen, ipod, ming,
# Nearest to rise: calibrated, zidane, follicles, unaccountable, target, unparalleled, poll, pnh,
# Nearest to frac: n, integral, cdots, sqrt, cdot, z, calculate, jacobi,
# Nearest to road: uffizi, reposition, bermuda, sausage, goatskin, tang, scanty, eidos,
# Nearest to lived: chalmers, meun, shih, formalist, empathic, jehovah, trillions, sisal,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2828 0.0670 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2982 0.0655 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3398 0.0361 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2841 0.0626 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2262 0.0661 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2343 0.0655 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2385 0.0652 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2166 0.0658 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2306 0.0668 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1758 0.0659 sec/batch
# Nearest to can: generic, quantities, interstellar, globus, torso, desirable, describing, cartesian,
# Nearest to state: enforceable, land, corrupt, determination, gunther, districts, painstaking, muskie,
# Nearest to eight: three, six, violinist, five, one, four, nelly, gomes,
# Nearest to five: three, one, six, four, zero, eight, per, infrastructural,
# Nearest to s: kanno, antonin, talked, veterans, nd, tzar, recording, surgeries,
# Nearest to be: however, mitosis, it, used, maccabean, values, bacteriophage, utilised,
# Nearest to not: honest, gotcha, dogmas, provoke, denial, porters, defend, debate,
# Nearest to but: exclaiming, leads, segmental, assumption, patently, anoints, immediate, mps,
# Nearest to resources: smelting, conseil, biodiversity, architectural, amg, arable, brahui, desertification,
# Nearest to event: sidestep, experiences, kambojas, monopolize, pasteurization, overbeck, spot, argue,
# Nearest to operating: kernel, compatibles, processors, chromodynamics, software, blantyre, architectures, implementations,
# Nearest to institute: bachelor, libre, engineering, dismemberment, ipod, ming, development, bergen,
# Nearest to rise: calibrated, follicles, zidane, target, unparalleled, shortfall, unaccountable, pnh,
# Nearest to frac: n, cdots, integral, cdot, sqrt, calculate, phi, logarithm,
# Nearest to road: uffizi, reposition, scanty, bermuda, sausage, hue, evergreen, tang,
# Nearest to lived: chalmers, meun, shih, empathic, formalist, jehovah, trillions, haunting,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2208 0.0657 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2257 0.0670 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2070 0.0663 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1538 0.0670 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1768 0.0671 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1445 0.0675 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1501 0.0651 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1628 0.0666 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2333 0.0666 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1883 0.0661 sec/batch
# Nearest to can: generic, desirable, reads, quantities, globus, instance, subscript, torso,
# Nearest to state: enforceable, hammond, determination, rm, gunther, painstaking, muskie, patriae,
# Nearest to eight: three, six, five, violinist, one, four, halt, nelly,
# Nearest to five: three, one, six, zero, four, eight, per, two,
# Nearest to s: antonin, nd, title, talked, kanno, butt, goofy, veterans,
# Nearest to be: mitosis, however, used, it, values, bacteriophage, follows, maccabean,
# Nearest to not: gotcha, honest, provoke, desired, dogmas, statements, person, sacrificial,
# Nearest to but: exclaiming, leads, segmental, immediate, anoints, patently, mps, assumption,
# Nearest to resources: smelting, architectural, conseil, amg, stanislavsky, arable, brahui, biodiversity,
# Nearest to event: sidestep, kambojas, experiences, pasteurization, monopolize, argue, arxiv, spot,
# Nearest to operating: kernel, architectures, compatibles, processors, chromodynamics, software, blantyre, implementations,
# Nearest to institute: bachelor, engineering, libre, vocational, ipod, dismemberment, residential, bergen,
# Nearest to rise: calibrated, follicles, target, unparalleled, zidane, unaccountable, pernoud, shortfall,
# Nearest to frac: n, integral, cdot, sqrt, cdots, follows, calculate, geq,
# Nearest to road: railway, sausage, reposition, scanty, evergreen, uffizi, waterway, bermuda,
# Nearest to lived: meun, chalmers, shih, empathic, formalist, sisal, trillions, haunting,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1938 0.0679 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1974 0.0654 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1593 0.0667 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1632 0.0655 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1863 0.0665 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1885 0.0661 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1730 0.0701 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1468 0.0621 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1508 0.0656 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1661 0.0661 sec/batch
# Nearest to can: generic, desirable, globus, quantities, interstellar, torso, instance, value,
# Nearest to state: enforceable, hammond, determination, rm, patriae, painstaking, districts, sewer,
# Nearest to eight: three, six, five, one, four, violinist, gomes, c,
# Nearest to five: three, one, six, zero, four, eight, two, per,
# Nearest to s: antonin, nd, butt, title, talked, goofy, longshanks, kanno,
# Nearest to be: mitosis, it, however, maccabean, used, values, algebras, infty,
# Nearest to not: provoke, honest, gotcha, statements, dogmas, debate, porters, person,
# Nearest to but: leads, exclaiming, segmental, immediate, assumption, patently, anoints, intravenously,
# Nearest to resources: smelting, conseil, arable, brahui, hydropower, architectural, amg, stanislavsky,
# Nearest to event: experiences, kambojas, sidestep, pasteurization, arxiv, argue, earthquakes, happening,
# Nearest to operating: kernel, compatibles, chromodynamics, blantyre, architectures, scripting, processors, software,
# Nearest to institute: bachelor, engineering, libre, vocational, education, bergen, residential, dismemberment,
# Nearest to rise: calibrated, unparalleled, follicles, shortfall, target, pernoud, fireplace, braudel,
# Nearest to frac: n, integral, cdot, sqrt, cdots, z, jacobi, logarithm,
# Nearest to road: railway, scanty, uffizi, waterway, obsolescence, reposition, hue, bermuda,
# Nearest to lived: meun, chalmers, shih, formalist, empathic, sisal, haunting, scrooge,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2148 0.0672 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1996 0.0679 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1570 0.0651 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1845 0.0671 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1486 0.0672 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1457 0.0675 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1559 0.0681 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1429 0.0667 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1875 0.0664 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2200 0.0697 sec/batch
# Nearest to can: generic, desirable, globus, situs, torso, reads, describing, moron,
# Nearest to state: enforceable, determination, patriae, hammond, corrupt, muskie, painstaking, renovate,
# Nearest to eight: three, six, one, five, four, violinist, gomes, seven,
# Nearest to five: one, three, six, four, zero, two, eight, seven,
# Nearest to s: antonin, butt, nd, cardano, title, veterans, talked, longshanks,
# Nearest to be: it, mitosis, maccabean, tripitaka, however, citing, utilised, used,
# Nearest to not: provoke, gotcha, honest, porters, pledge, sayyaf, sacrificial, ryle,
# Nearest to but: exclaiming, leads, segmental, immediate, mps, dublin, anoints, patently,
# Nearest to resources: smelting, hydropower, arable, conseil, biodiversity, brahui, desertification, architectural,
# Nearest to event: kambojas, sidestep, experiences, arxiv, pasteurization, argue, sfor, earthquakes,
# Nearest to operating: kernel, blantyre, architectures, chromodynamics, compatibles, processors, leeching, encapsulation,
# Nearest to institute: bachelor, engineering, libre, vocational, education, fellowship, residential, bergen,
# Nearest to rise: calibrated, unparalleled, shortfall, braudel, expanding, pernoud, fireplace, follicles,
# Nearest to frac: n, cdot, sqrt, cdots, integral, geq, logarithm, jacobi,
# Nearest to road: railway, uffizi, obsolescence, scanty, reposition, confided, waterway, bermuda,
# Nearest to lived: meun, shih, chalmers, empathic, formalist, sisal, haunting, dares,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2387 0.0650 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1516 0.0655 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1422 0.0660 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1466 0.0662 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0389 0.0667 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1328 0.0665 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1512 0.0661 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1384 0.0652 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1813 0.0157 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1069 0.0659 sec/batch
# Nearest to can: generic, desirable, globus, situs, reads, torso, subscript, instance,
# Nearest to state: enforceable, hammond, rm, determination, missouri, districts, painstaking, patriae,
# Nearest to eight: three, six, five, one, four, violinist, two, seven,
# Nearest to five: one, three, six, zero, four, two, eight, per,
# Nearest to s: butt, cardano, title, talked, shrewd, kanno, antonin, nexus,
# Nearest to be: mitosis, it, signatures, however, maccabean, tripitaka, utilised, used,
# Nearest to not: provoke, honest, gotcha, bcc, desired, pledge, porters, person,
# Nearest to but: exclaiming, leads, segmental, immediate, intravenously, firework, dublin, mps,
# Nearest to resources: smelting, hydropower, brahui, arable, conseil, architectural, stanislavsky, amg,
# Nearest to event: sidestep, experiences, kambojas, argue, happening, pasteurization, sfor, moderates,
# Nearest to operating: kernel, software, unix, architectures, chromodynamics, processors, compatibles, encapsulation,
# Nearest to institute: bachelor, engineering, libre, fellowship, vocational, bergen, residential, education,
# Nearest to rise: calibrated, unparalleled, shortfall, expanding, braudel, follicles, pernoud, apostates,
# Nearest to frac: n, geq, integral, cdots, sqrt, cdot, phi, right,
# Nearest to road: railway, sausage, obsolescence, scanty, evergreen, confided, huddle, reposition,
# Nearest to lived: meun, shih, chalmers, empathic, formalist, sisal, crater, haunting,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0542 0.0672 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0564 0.0660 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1132 0.0657 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0508 0.0652 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0615 0.0689 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0250 0.0616 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0847 0.0669 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0906 0.0659 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1364 0.0658 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0163 0.0676 sec/batch
# Nearest to can: generic, globus, desirable, torso, situs, reads, latent, sheets,
# Nearest to state: enforceable, hammond, painstaking, rm, determination, patriae, delegations, missouri,
# Nearest to eight: three, five, six, one, four, violinist, sultanate, seven,
# Nearest to five: one, three, six, four, zero, two, eight, per,
# Nearest to s: shrewd, butt, kanno, title, cardano, longshanks, nd, elbaradei,
# Nearest to be: it, mitosis, maccabean, tripitaka, however, chordates, used, signatures,
# Nearest to not: provoke, gotcha, honest, person, porters, pledge, hold, bcc,
# Nearest to but: exclaiming, leads, segmental, lightly, immediate, firework, dublin, patently,
# Nearest to resources: smelting, brahui, hydropower, arable, conseil, architectural, stanislavsky, allafrica,
# Nearest to event: experiences, sidestep, kambojas, argue, moderates, sfor, earthquakes, happening,
# Nearest to operating: kernel, software, chromodynamics, architectures, unix, encapsulation, blantyre, compatibles,
# Nearest to institute: bachelor, engineering, libre, fellowship, vocational, ming, residential, bergen,
# Nearest to rise: calibrated, expanding, pernoud, unparalleled, shortfall, braudel, follicles, nico,
# Nearest to frac: n, integral, geq, sqrt, cdots, cdot, right, dsa,
# Nearest to road: railway, reposition, huddle, waterway, confided, scanty, sausage, evergreen,
# Nearest to lived: meun, shih, chalmers, formalist, empathic, sisal, duomo, haunting,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0229 0.0682 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0458 0.0669 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0291 0.0703 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0367 0.0660 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0634 0.0661 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0483 0.0682 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0797 0.0656 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0751 0.0674 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0549 0.0696 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0547 0.0631 sec/batch
# Nearest to can: generic, desirable, instance, globus, situs, moron, value, reads,
# Nearest to state: hammond, enforceable, missouri, rm, portland, patriae, painstaking, renovate,
# Nearest to eight: three, six, five, one, four, older, seven, gomes,
# Nearest to five: one, three, six, zero, four, two, eight, per,
# Nearest to s: butt, distribution, title, cardano, nd, shrewd, zero, hostetler,
# Nearest to be: mitosis, it, used, tripitaka, however, values, macroeconomics, is,
# Nearest to not: provoke, person, inclusion, unless, statements, bcc, honest, gotcha,
# Nearest to but: exclaiming, leads, immediate, segmental, assumption, intravenously, patently, vanishes,
# Nearest to resources: smelting, brahui, hydropower, arable, architectural, stanislavsky, biodiversity, conseil,
# Nearest to event: experiences, sidestep, argue, kambojas, happening, pasteurization, sfor, moderates,
# Nearest to operating: kernel, netware, chromodynamics, unix, blantyre, software, compatibles, processors,
# Nearest to institute: bachelor, engineering, libre, fellowship, vocational, residential, bergen, development,
# Nearest to rise: calibrated, expanding, shortfall, unparalleled, follicles, pernoud, braudel, apostates,
# Nearest to frac: right, integral, sqrt, cdots, n, geq, cdot, left,
# Nearest to road: railway, waterway, commuter, huddle, reposition, roads, penn, confided,
# Nearest to lived: meun, shih, formalist, empathic, sisal, chalmers, sandals, haunting,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0596 0.0659 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0964 0.0673 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1183 0.0661 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0719 0.0653 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0553 0.0667 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0585 0.0651 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0638 0.0656 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0571 0.0701 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0730 0.0610 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0728 0.0658 sec/batch
# Nearest to can: generic, globus, desirable, reads, situs, moron, torso, instance,
# Nearest to state: enforceable, hammond, patriae, rm, missouri, delegations, determination, portland,
# Nearest to eight: three, six, one, five, four, two, seven, older,
# Nearest to five: one, three, four, six, zero, two, eight, seven,
# Nearest to s: nd, cardano, elbaradei, butt, kerensky, title, nexus, longshanks,
# Nearest to be: it, mitosis, tripitaka, chordates, maccabean, used, declensions, values,
# Nearest to not: provoke, person, hold, repentance, unless, pledge, porters, honest,
# Nearest to but: exclaiming, leads, immediate, segmental, dublin, anoints, patently, lightly,
# Nearest to resources: smelting, hydropower, brahui, arable, biodiversity, conseil, stanislavsky, amg,
# Nearest to event: experiences, sidestep, happening, kambojas, sfor, argue, moderates, earthquakes,
# Nearest to operating: kernel, netware, blantyre, software, chromodynamics, unix, leeching, sponsors,
# Nearest to institute: bachelor, engineering, libre, fellowship, vocational, bergen, residential, research,
# Nearest to rise: calibrated, expanding, unparalleled, braudel, shortfall, pernoud, follicles, fireplace,
# Nearest to frac: cdots, cdot, sqrt, integral, geq, right, cos, dsa,
# Nearest to road: railway, penn, huddle, waterway, confided, obsolescence, reposition, uffizi,
# Nearest to lived: shih, meun, formalist, sisal, empathic, haunting, chalmers, parents,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0820 0.0687 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0197 0.0705 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0555 0.0631 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0637 0.0710 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0760 0.0619 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1111 0.0659 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1464 0.0657 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0473 0.0664 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0228 0.0659 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0551 0.0659 sec/batch
# Nearest to can: generic, reads, globus, desirable, latent, instance, moron, situs,
# Nearest to state: enforceable, determination, hammond, patriae, statewide, delegations, rm, missouri,
# Nearest to eight: three, one, six, five, four, two, seven, nine,
# Nearest to five: one, three, zero, four, six, two, eight, seven,
# Nearest to s: butt, distribution, cardano, nd, longshanks, kerensky, nexus, megabits,
# Nearest to be: it, mitosis, tripitaka, declensions, maccabean, however, chordates, values,
# Nearest to not: provoke, person, hold, honest, porters, does, inclusion, unless,
# Nearest to but: exclaiming, leads, segmental, immediate, dublin, firework, intravenously, anoints,
# Nearest to resources: smelting, hydropower, arable, brahui, biodiversity, conseil, allafrica, stanislavsky,
# Nearest to event: experiences, sfor, sidestep, happening, kambojas, earthquakes, arxiv, moderates,
# Nearest to operating: kernel, netware, blantyre, software, unix, chromodynamics, leeching, architectures,
# Nearest to institute: bachelor, engineering, libre, fellowship, vocational, bergen, ming, residential,
# Nearest to rise: calibrated, expanding, shortfall, unparalleled, braudel, pernoud, sepiroth, mobutu,
# Nearest to frac: sqrt, cdot, integral, cos, right, jacobi, n, geq,
# Nearest to road: confided, huddle, railway, laurens, penn, obsolescence, uffizi, reposition,
# Nearest to lived: shih, meun, formalist, empathic, parents, sisal, chalmers, duomo,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9927 0.0679 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0366 0.0669 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0367 0.0675 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0557 0.0664 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0654 0.0672 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0358 0.0637 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0266 0.0647 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0003 0.0659 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0178 0.0659 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.0073 0.0655 sec/batch
# Nearest to can: globus, intolerable, latent, generic, reads, moron, torso, molecules,
# Nearest to state: hammond, missouri, enforceable, statewide, patriae, determination, delegations, portland,
# Nearest to eight: three, one, six, five, four, two, nine, seven,
# Nearest to five: four, one, three, six, zero, two, eight, seven,
# Nearest to s: cardano, nd, butt, distribution, kerensky, hostetler, nexus, tzar,
# Nearest to be: it, mitosis, however, tripitaka, declensions, chordates, used, maccabean,
# Nearest to not: provoke, person, hold, honest, pledge, unless, porters, repentance,
# Nearest to but: exclaiming, leads, dublin, immediate, firework, segmental, intravenously, anoints,
# Nearest to resources: smelting, hydropower, brahui, conseil, arable, biodiversity, stanislavsky, allafrica,
# Nearest to event: experiences, sfor, pasteurization, earthquakes, happening, moderates, kambojas, sidestep,
# Nearest to operating: kernel, netware, unix, blantyre, software, chromodynamics, architectures, amputees,
# Nearest to institute: bachelor, engineering, fellowship, vocational, libre, bergen, graduates, residential,
# Nearest to rise: calibrated, expanding, shortfall, pernoud, unparalleled, braudel, sepiroth, follicles,
# Nearest to frac: sqrt, cdot, integral, right, cos, geq, dsa, n,
# Nearest to road: railway, confided, huddle, laurens, reposition, commuter, penn, waterway,
# Nearest to lived: shih, meun, empathic, formalist, parents, chalmers, battled, sisal,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9833 0.0671 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9417 0.0674 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0589 0.0646 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0219 0.0668 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0233 0.0668 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9906 0.0659 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9145 0.0671 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9838 0.0665 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9026 0.0665 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9995 0.0658 sec/batch
# Nearest to can: reads, globus, molecules, torso, latent, intolerable, desirable, generic,
# Nearest to state: hammond, enforceable, missouri, statewide, determination, patriae, delegations, portland,
# Nearest to eight: three, one, six, five, four, two, seven, nine,
# Nearest to five: six, one, zero, four, three, two, eight, seven,
# Nearest to s: nd, the, butt, cardano, hostetler, longshanks, kanno, distribution,
# Nearest to be: it, infty, mitosis, declensions, is, tripitaka, values, signatures,
# Nearest to not: person, unless, provoke, hold, if, does, bcc, pledge,
# Nearest to but: leads, exclaiming, immediate, segmental, dublin, lightly, firework, intravenously,
# Nearest to resources: smelting, hydropower, conseil, brahui, arable, allafrica, bibliography, agent,
# Nearest to event: experiences, sfor, implied, happening, pasteurization, earthquakes, sidestep, kambojas,
# Nearest to operating: kernel, netware, unix, chromodynamics, blantyre, software, encapsulation, jeet,
# Nearest to institute: engineering, bachelor, fellowship, libre, vocational, bergen, residential, ming,
# Nearest to rise: calibrated, expanding, shortfall, unparalleled, pernoud, braudel, nico, follicles,
# Nearest to frac: cdot, sqrt, right, integral, geq, dsa, cdots, follows,
# Nearest to road: railway, huddle, penn, laurens, reposition, confided, waterway, commuter,
# Nearest to lived: shih, meun, empathic, formalist, sisal, occurring, battled, duomo,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0092 0.0672 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9938 0.0668 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9962 0.0662 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9961 0.0662 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0059 0.0665 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9551 0.0666 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9896 0.0669 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0040 0.0659 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9968 0.0662 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0320 0.0667 sec/batch
# Nearest to can: generic, moron, reads, globus, subscript, instance, intolerable, situs,
# Nearest to state: hammond, missouri, enforceable, patriae, gunther, determination, statewide, discretion,
# Nearest to eight: three, one, six, five, four, nine, seven, two,
# Nearest to five: four, one, three, six, zero, two, eight, seven,
# Nearest to s: the, butt, nd, hostetler, cardano, distribution, nexus, title,
# Nearest to be: it, used, infty, declensions, however, mitosis, tripitaka, is,
# Nearest to not: provoke, person, unless, does, if, hold, inclusion, bcc,
# Nearest to but: exclaiming, leads, segmental, immediate, vanishes, dublin, anoints, basilides,
# Nearest to resources: smelting, brahui, hydropower, conseil, agent, arable, archived, amg,
# Nearest to event: experiences, happening, implied, sfor, earthquakes, arxiv, zeno, kambojas,
# Nearest to operating: kernel, netware, blantyre, chromodynamics, unix, amputees, sponsors, software,
# Nearest to institute: engineering, bachelor, fellowship, libre, bergen, residential, ming, planets,
# Nearest to rise: calibrated, expanding, unparalleled, nico, pernoud, shortfall, braudel, rejection,
# Nearest to frac: cdot, right, integral, cos, sqrt, dsa, left, mbox,
# Nearest to road: laurens, railway, penn, reposition, huddle, waterway, competes, confided,
# Nearest to lived: shih, meun, formalist, empathic, sisal, retorted, haunting, parents,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9954 0.0674 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9749 0.0674 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9852 0.0666 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9798 0.0657 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0253 0.0658 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0024 0.0646 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9865 0.0651 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9653 0.0659 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9622 0.0655 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0247 0.0662 sec/batch
# Nearest to can: generic, globus, reads, molecules, instance, moron, intolerable, do,
# Nearest to state: enforceable, missouri, patriae, hammond, delegations, determination, statewide, furthest,
# Nearest to eight: three, one, six, five, four, nine, two, seven,
# Nearest to five: one, three, zero, six, four, two, eight, seven,
# Nearest to s: the, zero, distribution, kerensky, nd, hostetler, and, nexus,
# Nearest to be: it, however, mitosis, declensions, is, used, tripitaka, this,
# Nearest to not: provoke, unless, does, hold, bcc, person, if, ever,
# Nearest to but: leads, exclaiming, segmental, immediate, tungusic, dublin, hungarian, intravenously,
# Nearest to resources: smelting, hydropower, brahui, arable, conseil, allafrica, biodiversity, archived,
# Nearest to event: experiences, implied, zeno, sfor, arxiv, happening, earthquakes, pasteurization,
# Nearest to operating: kernel, netware, blantyre, chromodynamics, unix, capacities, leeching, jeet,
# Nearest to institute: engineering, bachelor, fellowship, ming, libre, futurology, bergen, residential,
# Nearest to rise: expanding, calibrated, unparalleled, shortfall, pernoud, braudel, nico, asu,
# Nearest to frac: dsa, right, cos, sqrt, cdot, nabla, varphi, integral,
# Nearest to road: laurens, railway, competes, penn, huddle, waterway, confided, reposition,
# Nearest to lived: shih, formalist, meun, retorted, empathic, occurring, battled, parents,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9657 0.0672 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0774 0.0657 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0214 0.0645 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0192 0.0675 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9563 0.0658 sec/batch
# ...
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8257 0.0658 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7906 0.0667 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8133 0.0670 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8720 0.0656 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8705 0.0668 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8352 0.0667 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8886 0.0668 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9125 0.0652 sec/batch
# Nearest to can: using, generic, see, reads, multiplexer, instance, subscript, than,
# Nearest to state: missouri, bordered, patriae, michigan, boltzmann, is, statewide, herg,
# Nearest to eight: one, six, three, five, four, nine, seven, two,
# Nearest to five: one, two, zero, six, four, three, eight, seven,
# Nearest to s: in, the, of, also, and, zero, a, two,
# Nearest to be: it, is, used, to, this, or, any, the,
# Nearest to not: have, also, does, to, are, that, unless, ever,
# Nearest to but: in, to, is, the, various, not, leads, exclaiming,
# Nearest to resources: smelting, bibliography, agent, archived, clearing, deploying, hydropower, deception,
# Nearest to event: happening, sfor, tevet, implied, summer, zeno, pasteurization, widebody,
# Nearest to operating: unix, jeet, kernel, amputees, netware, blantyre, placements, chromodynamics,
# Nearest to institute: futurology, engineering, tech, bergen, fellowship, technik, theologians, henrique,
# Nearest to rise: calibrated, shortfall, pernoud, output, late, fireplace, asu, hypnotherapy,
# Nearest to frac: left, right, dsa, cos, sqrt, depress, nir, nabla,
# Nearest to road: mistaking, laurens, tampere, roads, penn, competes, assistant, waterway,
# Nearest to lived: dares, shih, considerably, isotope, dressers, parents, battled, went,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7981 0.0684 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8500 0.0658 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8572 0.0655 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8728 0.0666 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8662 0.0662 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8888 0.0668 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8690 0.0667 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8503 0.0662 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8798 0.0655 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8772 0.0662 sec/batch
# Nearest to can: generic, people, reads, using, see, prevents, headaches, ignorance,
# Nearest to state: is, patriae, bordered, governor, missouri, boltzmann, infinitude, delegations,
# Nearest to eight: one, six, three, nine, five, four, seven, two,
# Nearest to five: one, two, six, three, zero, four, eight, seven,
# Nearest to s: in, of, the, also, and, one, zero, two,
# Nearest to be: it, used, is, this, to, however, called, any,
# Nearest to not: have, also, unless, does, are, but, ever, to,
# Nearest to but: in, to, not, exclaiming, various, is, however, leads,
# Nearest to resources: smelting, bibliography, hydropower, clearing, agent, arable, archived, permanent,
# Nearest to event: happening, sfor, tevet, implied, zeno, summer, disraeli, eurovision,
# Nearest to operating: unix, jeet, amputees, netware, kernel, blantyre, placements, sponsors,
# Nearest to institute: futurology, engineering, theologians, crossfire, tech, bergen, technik, fellowship,
# Nearest to rise: calibrated, shortfall, pernoud, output, fireplace, aramid, late, asu,
# Nearest to frac: dsa, right, left, cos, sqrt, depress, torsion, adolph,
# Nearest to road: laurens, mistaking, tampere, roads, penn, competes, waterway, assistant,
# Nearest to lived: shih, dares, considerably, isotope, went, parents, dressers, occurring,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8414 0.0664 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8229 0.0661 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8459 0.0664 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8204 0.0653 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9273 0.0670 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8459 0.0662 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9546 0.0664 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8705 0.0657 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8989 0.0659 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8271 0.0664 sec/batch
# Nearest to can: generic, using, reads, prevents, ignorance, see, instance, cannot,
# Nearest to state: patriae, is, bordered, missouri, governor, delegations, michigan, boltzmann,
# Nearest to eight: one, six, four, three, five, nine, seven, two,
# Nearest to five: one, two, four, six, three, zero, seven, eight,
# Nearest to s: in, of, the, and, also, from, one, zero,
# Nearest to be: it, is, used, this, any, however, has, called,
# Nearest to not: have, does, unless, also, ever, hold, stated, bromley,
# Nearest to but: in, to, however, various, compensated, been, exclaiming, processors,
# Nearest to resources: smelting, hydropower, arable, bibliography, permanent, clearing, archived, liebster,
# Nearest to event: sfor, happening, tevet, zeno, pasteurization, implied, disraeli, eurovision,
# Nearest to operating: unix, jeet, amputees, kernel, blantyre, netware, placements, sickle,
# Nearest to institute: futurology, theologians, bergen, crossfire, engineering, technik, henrique, fellowship,
# Nearest to rise: calibrated, shortfall, late, pernoud, output, fireplace, aramid, hypnotherapy,
# Nearest to frac: right, dsa, left, sqrt, cos, metastasis, adolph, cdot,
# Nearest to road: laurens, mistaking, tampere, penn, competes, roads, noor, harbours,
# Nearest to lived: shih, considerably, isotope, dares, parents, went, dressers, pancreatitis,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7981 0.0684 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8469 0.0665 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7932 0.0664 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8516 0.0670 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8130 0.0660 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8474 0.0655 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8806 0.0446 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8366 0.0673 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8271 0.0673 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8775 0.0657 sec/batch
# Nearest to can: generic, reads, using, do, prevents, people, see, cannot,
# Nearest to state: bordered, patriae, is, michigan, missouri, governor, of, delegations,
# Nearest to eight: one, six, nine, five, four, three, seven, two,
# Nearest to five: one, two, four, six, three, zero, eight, seven,
# Nearest to s: in, the, of, and, also, zero, a, for,
# Nearest to be: it, is, used, this, to, any, a, however,
# Nearest to not: have, unless, also, does, to, ever, hold, if,
# Nearest to but: in, to, various, the, however, a, been, exclaiming,
# Nearest to resources: bibliography, smelting, agent, hydropower, liebster, arable, archived, permanent,
# Nearest to event: happening, sfor, tevet, pasteurization, disraeli, zeno, eurovision, summer,
# Nearest to operating: unix, jeet, amputees, kernel, placements, netware, blantyre, sickle,
# Nearest to institute: futurology, engineering, bergen, theologians, tech, fellowship, crossfire, technik,
# Nearest to rise: shortfall, calibrated, pernoud, output, late, fireplace, aramid, hypnotherapy,
# Nearest to frac: right, left, sqrt, cos, cdot, dsa, nabla, adolph,
# Nearest to road: laurens, mistaking, tampere, roads, competes, harbours, penn, noor,
# Nearest to lived: shih, isotope, dares, considerably, been, inst, dressers, occurring,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8071 0.0666 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8277 0.0660 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7980 0.0656 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8535 0.0650 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8541 0.0659 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8574 0.0665 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8753 0.0674 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7147 0.0663 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8191 0.0667 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8001 0.0663 sec/batch
# Nearest to can: using, generic, reads, other, see, do, preregular, cannot,
# Nearest to state: bordered, patriae, governor, michigan, missouri, is, boltzmann, delegations,
# Nearest to eight: one, three, six, five, nine, four, two, seven,
# Nearest to five: two, four, one, three, six, zero, eight, seven,
# Nearest to s: in, of, the, and, also, zero, two, from,
# Nearest to be: it, is, a, any, this, used, to, the,
# Nearest to not: does, have, also, are, as, to, that, unless,
# Nearest to but: in, to, various, the, is, however, as, not,
# Nearest to resources: bibliography, hydropower, smelting, clearing, arable, agent, liebster, permanent,
# Nearest to event: tevet, happening, sfor, pasteurization, zeno, attracts, disraeli, eurovision,
# Nearest to operating: unix, jeet, amputees, kernel, placements, sickle, blantyre, netware,
# Nearest to institute: futurology, engineering, bergen, theologians, tech, crossfire, technik, fellowship,
# Nearest to rise: calibrated, shortfall, pernoud, late, output, aramid, fireplace, asu,
# Nearest to frac: right, left, sqrt, cdot, cos, adolph, depress, nabla,
# Nearest to road: mistaking, laurens, tampere, harbours, roads, competes, waterway, penn,
# Nearest to lived: isotope, shih, dares, occurring, considerably, been, inst, parents,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7803 0.0672 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8230 0.0675 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8683 0.0682 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8216 0.0665 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8455 0.0654 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8991 0.0666 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7953 0.0656 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8257 0.0655 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8219 0.0655 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8469 0.0669 sec/batch
# Nearest to can: generic, using, reads, preregular, see, cics, instance, commonly,
# Nearest to state: is, bordered, boltzmann, patriae, missouri, michigan, governor, of,
# Nearest to eight: one, six, four, five, three, nine, seven, two,
# Nearest to five: two, four, one, three, zero, six, eight, nine,
# Nearest to s: in, of, the, and, also, for, a, zero,
# Nearest to be: it, is, used, this, a, the, any, for,
# Nearest to not: have, also, does, unless, are, to, but, if,
# Nearest to but: in, to, however, not, is, various, the, with,
# Nearest to resources: bibliography, smelting, clearing, hydropower, deception, liebster, agent, arable,
# Nearest to event: tevet, happening, sfor, attracts, pasteurization, zeno, extinction, disraeli,
# Nearest to operating: unix, jeet, amputees, kernel, placements, sickle, sponsors, netware,
# Nearest to institute: futurology, bergen, engineering, theologians, tech, technik, crossfire, ucsb,
# Nearest to rise: shortfall, calibrated, pernoud, output, late, hypnotherapy, aramid, fireplace,
# Nearest to frac: left, right, cos, cdot, nabla, sqrt, adolph, isobaric,
# Nearest to road: mistaking, laurens, tampere, penn, roads, waterway, harbours, noor,
# Nearest to lived: shih, isotope, dares, considerably, inst, dressers, spiro, was,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8341 0.0669 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8483 0.0655 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8315 0.0658 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7912 0.0661 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8638 0.0672 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8658 0.0668 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8190 0.0666 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8734 0.0656 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8047 0.0673 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8532 0.0671 sec/batch
# Nearest to can: generic, reads, using, than, cannot, see, commonly, uses,
# Nearest to state: bordered, is, governor, boltzmann, patriae, of, missouri, delegations,
# Nearest to eight: one, six, five, four, three, nine, two, seven,
# Nearest to five: two, one, four, six, three, zero, eight, seven,
# Nearest to s: in, of, the, and, also, zero, one, two,
# Nearest to be: it, used, is, this, for, a, to, any,
# Nearest to not: have, does, also, are, unless, but, to, as,
# Nearest to but: in, to, however, not, various, is, been, the,
# Nearest to resources: bibliography, smelting, hydropower, permanent, arable, clearing, liebster, deception,
# Nearest to event: tevet, sfor, happening, zeno, disraeli, pasteurization, implied, attracts,
# Nearest to operating: unix, jeet, kernel, amputees, placements, netware, blantyre, sickle,
# Nearest to institute: futurology, bergen, tech, crossfire, engineering, theologians, technik, marathi,
# Nearest to rise: shortfall, calibrated, pernoud, late, aramid, output, asu, hypnotherapy,
# Nearest to frac: right, left, cos, nabla, sqrt, adolph, nir, dsa,
# Nearest to road: laurens, mistaking, tampere, roads, harbours, noor, penn, competes,
# Nearest to lived: isotope, shih, dares, considerably, dressers, went, occurring, neanderthals,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8690 0.0670 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8239 0.0673 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9280 0.0649 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8873 0.0673 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8732 0.0673 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8074 0.0649 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7849 0.0657 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8454 0.0666 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7441 0.0662 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8551 0.0657 sec/batch
# Nearest to can: using, reads, generic, cannot, other, than, uses, see,
# Nearest to state: bordered, is, governor, michigan, of, missouri, patriae, dolmens,
# Nearest to eight: one, six, nine, five, four, three, seven, two,
# Nearest to five: two, one, four, six, zero, three, eight, seven,
# Nearest to s: in, the, of, and, also, for, zero, from,
# Nearest to be: it, is, used, this, a, or, any, for,
# Nearest to not: have, does, but, also, unless, to, hold, it,
# Nearest to but: in, to, however, not, various, been, still, as,
# Nearest to resources: bibliography, permanent, smelting, arable, liebster, hydropower, deploying, deception,
# Nearest to event: happening, sfor, tevet, disraeli, eurovision, pasteurization, implied, zeno,
# Nearest to operating: unix, jeet, kernel, amputees, sponsors, placements, system, sickle,
# Nearest to institute: futurology, tech, bergen, engineering, crossfire, theologians, technik, streamlining,
# Nearest to rise: shortfall, late, pernoud, calibrated, output, psychopharmacology, aramid, per,
# Nearest to frac: right, left, cos, nabla, adolph, cdots, sqrt, dsa,
# Nearest to road: mistaking, laurens, roads, tampere, harbours, noor, competes, huddle,
# Nearest to lived: shih, isotope, dares, considerably, dressers, neanderthals, went, inst,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8423 0.0672 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8103 0.0654 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

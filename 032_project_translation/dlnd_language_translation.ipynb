# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    def process_sequence(txt, dct, is_t = False):
        r = []
        for l in txt.lower().split('\n'):
            c = []
            for w in l.split():
                c.append(dct[w])
            if is_t:
                c.append(dct['<EOS>'])
            r.append(c)
        return r
    r_1 = process_sequence(source_text, source_vocab_to_int)
    r_2 = process_sequence(target_text, target_vocab_to_int, True)
   
    return r_1, r_2

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.2.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    input_data = tf.placeholder(tf.int32, [None, None], name='input_data')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    target_sequence_length = tf.placeholder(tf.int32, [None, ], name='target_sequence_length')
    max_target_sequence_length = tf.reduce_max(target_sequence_length, name='max_target_len')
    source_sequence_length = tf.placeholder(tf.int32, [None, ], name='source_sequence_length')
    return input_data, targets, learning_rate, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_2/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\runpy.py", line 193, in _run_module_as_main\n    "__main__", mod_spec)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel_launcher.py", line 16, in <module>\n    app.launch_new_instance()', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\traitlets\\config\\application.py", line 658, in launch_instance\n    app.start()', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\kernelapp.py", line 477, in start\n    ioloop.IOLoop.instance().start()', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\zmq\\eventloop\\ioloop.py", line 177, in start\n    super(ZMQIOLoop, self).start()', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\tornado\\ioloop.py", line 888, in start\n    handler_func(fd_obj, events)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\tornado\\stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\tornado\\stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\kernelbase.py", line 283, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\kernelbase.py", line 235, in dispatch_shell\n    handler(stream, idents, msg)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\kernelbase.py", line 399, in execute_request\n    user_expressions, allow_stdin)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\zmqshell.py", line 533, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2698, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2808, in run_ast_nodes\n    if self.run_code(code, result):', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2862, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-3-15d8d896ee1e>", line 20, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "C:\\OneDrive\\Projects\\UdacityLearning\\032_project_translation\\problem_unittests.py", line 106, in test_model_inputs\n    assert tf.assert_rank(lr, 0, message=\'Learning Rate has wrong rank\')', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\tensorflow\\python\\ops\\check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\tensorflow\\python\\ops\\check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "c:\\anaconda ...
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_3/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\runpy.py", line 193, in _run_module_as_main\n    "__main__", mod_spec)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel_launcher.py", line 16, in <module>\n    app.launch_new_instance()', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\traitlets\\config\\application.py", line 658, in launch_instance\n    app.start()', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\kernelapp.py", line 477, in start\n    ioloop.IOLoop.instance().start()', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\zmq\\eventloop\\ioloop.py", line 177, in start\n    super(ZMQIOLoop, self).start()', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\tornado\\ioloop.py", line 888, in start\n    handler_func(fd_obj, events)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\tornado\\stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\tornado\\stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\kernelbase.py", line 283, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\kernelbase.py", line 235, in dispatch_shell\n    handler(stream, idents, msg)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\kernelbase.py", line 399, in execute_request\n    user_expressions, allow_stdin)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\ipykernel\\zmqshell.py", line 533, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2698, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2808, in run_ast_nodes\n    if self.run_code(code, result):', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2862, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-3-15d8d896ee1e>", line 20, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "C:\\OneDrive\\Projects\\UdacityLearning\\032_project_translation\\problem_unittests.py", line 107, in test_model_inputs\n    assert tf.assert_rank(keep_prob, 0, message=\'Keep Probability has wrong rank\')', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\tensorflow\\python\\ops\\check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "c:\\anaconda3\\envs\\udacity_learning_2_35\\lib\\site-packages\\tensorflow\\python\\ops\\check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "c: ...
# ==================================
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    def make_cell(rnn_size):
        enc_cell = tf.contrib.rnn.LSTMCell(rnn_size)
        drop = tf.contrib.rnn.DropoutWrapper(enc_cell, output_keep_prob=keep_prob)
        return drop
    # Encoder embedding
    enc_embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)
    
    # Stack up multiple LSTM layers, for deep learning
    enc_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    
    enc_output, enc_state = tf.nn.dynamic_rnn(
        enc_cell, 
        enc_embed_input, 
        sequence_length=source_sequence_length, 
        dtype=tf.float32
    )
    return enc_output, enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    drop =  tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input, sequence_length=target_sequence_length, time_major=False)
    training_decoder = tf.contrib.seq2seq.BasicDecoder(drop, training_helper, encoder_state, output_layer)
    training_decoder_output, _, __ = tf.contrib.seq2seq.dynamic_decode(training_decoder, impute_finished=True, maximum_iterations=max_summary_length)
    
    return training_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state !
    :param dec_cell: Decoder RNN Cell !
    :param dec_embeddings: Decoder embeddings !
    :param start_of_sequence_id: GO ID !
    :param end_of_sequence_id: EOS Id !
    :param max_target_sequence_length: Maximum length of target sequences !
    :param vocab_size: Size of decoder/target vocabulary
    :param output_layer: Function to apply the output layer !
    :param batch_size: Batch size !
    :param keep_prob: Dropout keep probability !
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    drop =  tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)

    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings, start_tokens, end_of_sequence_id)
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(drop, inference_helper, encoder_state, output_layer)
    inference_decoder_output, _, __ = tf.contrib.seq2seq.dynamic_decode(
        inference_decoder,
        impute_finished=True,
        maximum_iterations=max_target_sequence_length
    )
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size !
    :param num_layers: Number of layers !
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    def make_cell(rnn_size):
        dec_cell = tf.contrib.rnn.LSTMCell(rnn_size)
        return dec_cell
    
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    

    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    output_layer = Dense(target_vocab_size, kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))
    
    with tf.variable_scope("decode"):
        training_decoder_output = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)
    with tf.variable_scope("decode", reuse=True):
        inference_decoder_output = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, target_vocab_to_int['<GO>'], target_vocab_to_int['<EOS>'], max_target_sequence_length, target_vocab_size, output_layer, batch_size, keep_prob) 
    
    return training_decoder_output, inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    _, encoder_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   enc_embedding_size)
    
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    training_decoder_output, inference_decoder_output = decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sentence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, dec_embedding_size)
    
    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 60
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 15
decoding_embedding_size = 15
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.5
display_step = 50

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   50/1077 - Train Accuracy: 0.2602, Validation Accuracy: 0.3363, Loss: 3.7936
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.2645, Validation Accuracy: 0.3377, Loss: 3.3932
# Epoch   0 Batch  150/1077 - Train Accuracy: 0.3616, Validation Accuracy: 0.3768, Loss: 2.9770
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.3523, Validation Accuracy: 0.4031, Loss: 2.9329
# Epoch   0 Batch  250/1077 - Train Accuracy: 0.4087, Validation Accuracy: 0.4229, Loss: 2.6439
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.3376, Validation Accuracy: 0.4318, Loss: 2.8984
# Epoch   0 Batch  350/1077 - Train Accuracy: 0.3680, Validation Accuracy: 0.4418, Loss: 2.7400
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.3973, Validation Accuracy: 0.4627, Loss: 2.5921
# Epoch   0 Batch  450/1077 - Train Accuracy: 0.4258, Validation Accuracy: 0.4759, Loss: 2.4980
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.4316, Validation Accuracy: 0.4780, Loss: 2.3830
# Epoch   0 Batch  550/1077 - Train Accuracy: 0.4191, Validation Accuracy: 0.4904, Loss: 2.4142
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.4807, Validation Accuracy: 0.4865, Loss: 2.1825
# Epoch   0 Batch  650/1077 - Train Accuracy: 0.4309, Validation Accuracy: 0.4872, Loss: 2.2472
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.4441, Validation Accuracy: 0.4911, Loss: 2.1098
# Epoch   0 Batch  750/1077 - Train Accuracy: 0.4402, Validation Accuracy: 0.4780, Loss: 2.0261
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.4375, Validation Accuracy: 0.5032, Loss: 1.9992
# Epoch   0 Batch  850/1077 - Train Accuracy: 0.4587, Validation Accuracy: 0.4996, Loss: 1.9184
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.4441, Validation Accuracy: 0.4893, Loss: 1.9222
# Epoch   0 Batch  950/1077 - Train Accuracy: 0.4542, Validation Accuracy: 0.4886, Loss: 1.7915
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.4825, Validation Accuracy: 0.4762, Loss: 1.6739
# Epoch   0 Batch 1050/1077 - Train Accuracy: 0.3914, Validation Accuracy: 0.4769, Loss: 1.7926
# Epoch   1 Batch   50/1077 - Train Accuracy: 0.4191, Validation Accuracy: 0.4755, Loss: 1.7090
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.4434, Validation Accuracy: 0.4904, Loss: 1.6119
# Epoch   1 Batch  150/1077 - Train Accuracy: 0.4632, Validation Accuracy: 0.4744, Loss: 1.5002
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.4398, Validation Accuracy: 0.4869, Loss: 1.5415
# Epoch   1 Batch  250/1077 - Train Accuracy: 0.4638, Validation Accuracy: 0.4933, Loss: 1.4078
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.4198, Validation Accuracy: 0.4972, Loss: 1.5625
# Epoch   1 Batch  350/1077 - Train Accuracy: 0.4594, Validation Accuracy: 0.5131, Loss: 1.5567
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.4629, Validation Accuracy: 0.5043, Loss: 1.4398
# Epoch   1 Batch  450/1077 - Train Accuracy: 0.4586, Validation Accuracy: 0.5121, Loss: 1.3962
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.4691, Validation Accuracy: 0.5053, Loss: 1.3515
# Epoch   1 Batch  550/1077 - Train Accuracy: 0.4539, Validation Accuracy: 0.5202, Loss: 1.3733
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.5052, Validation Accuracy: 0.5032, Loss: 1.2815
# Epoch   1 Batch  650/1077 - Train Accuracy: 0.4695, Validation Accuracy: 0.5135, Loss: 1.3043
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.4715, Validation Accuracy: 0.5153, Loss: 1.2469
# Epoch   1 Batch  750/1077 - Train Accuracy: 0.4867, Validation Accuracy: 0.5217, Loss: 1.2125
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.4555, Validation Accuracy: 0.5153, Loss: 1.2631
# Epoch   1 Batch  850/1077 - Train Accuracy: 0.5022, Validation Accuracy: 0.5281, Loss: 1.2538
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.4832, Validation Accuracy: 0.5138, Loss: 1.2235
# Epoch   1 Batch  950/1077 - Train Accuracy: 0.5074, Validation Accuracy: 0.5394, Loss: 1.1456
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.5465, Validation Accuracy: 0.5337, Loss: 1.0866
# Epoch   1 Batch 1050/1077 - Train Accuracy: 0.4461, Validation Accuracy: 0.5316, Loss: 1.1961
# Epoch   2 Batch   50/1077 - Train Accuracy: 0.4883, Validation Accuracy: 0.5266, Loss: 1.1426
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.5086, Validation Accuracy: 0.5259, Loss: 1.0901
# Epoch   2 Batch  150/1077 - Train Accuracy: 0.5368, Validation Accuracy: 0.5149, Loss: 1.0155
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.4875, Validation Accuracy: 0.5369, Loss: 1.0710
# Epoch   2 Batch  250/1077 - Train Accuracy: 0.5359, Validation Accuracy: 0.5362, Loss: 0.9872
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.4926, Validation Accuracy: 0.5291, Loss: 1.0861
# Epoch   2 Batch  350/1077 - Train Accuracy: 0.4992, Validation Accuracy: 0.5526, Loss: 1.0914
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.5324, Validation Accuracy: 0.5490, Loss: 1.0221
# Epoch   2 Batch  450/1077 - Train Accuracy: 0.5094, Validation Accuracy: 0.5312, Loss: 1.0090
# Epoch   2 Batch  500/1077 - Train Accuracy: 0.5426, Validation Accuracy: 0.5568, Loss: 0.9927
# Epoch   2 Batch  550/1077 - Train Accuracy: 0.5340, Validation Accuracy: 0.5501, Loss: 1.0363
# Epoch   2 Batch  600/1077 - Train Accuracy: 0.6031, Validation Accuracy: 0.5632, Loss: 0.9269
# Epoch   2 Batch  650/1077 - Train Accuracy: 0.5379, Validation Accuracy: 0.5526, Loss: 0.9929
# Epoch   2 Batch  700/1077 - Train Accuracy: 0.5473, Validation Accuracy: 0.5547, Loss: 0.9470
# Epoch   2 Batch  750/1077 - Train Accuracy: 0.5762, Validation Accuracy: 0.5682, Loss: 0.9343
# Epoch   2 Batch  800/1077 - Train Accuracy: 0.5484, Validation Accuracy: 0.5494, Loss: 0.9521
# Epoch   2 Batch  850/1077 - Train Accuracy: 0.5420, Validation Accuracy: 0.5614, Loss: 0.9862
# Epoch   2 Batch  900/1077 - Train Accuracy: 0.5801, Validation Accuracy: 0.5845, Loss: 0.9447
# Epoch   2 Batch  950/1077 - Train Accuracy: 0.5614, Validation Accuracy: 0.5671, Loss: 0.8870
# Epoch   2 Batch 1000/1077 - Train Accuracy: 0.6168, Validation Accuracy: 0.5874, Loss: 0.8304
# Epoch   2 Batch 1050/1077 - Train Accuracy: 0.5113, Validation Accuracy: 0.5831, Loss: 0.9353
# Epoch   3 Batch   50/1077 - Train Accuracy: 0.5402, Validation Accuracy: 0.5831, Loss: 0.9075
# Epoch   3 Batch  100/1077 - Train Accuracy: 0.5891, Validation Accuracy: 0.5866, Loss: 0.8840
# Epoch   3 Batch  150/1077 - Train Accuracy: 0.6004, Validation Accuracy: 0.5721, Loss: 0.8113
# Epoch   3 Batch  200/1077 - Train Accuracy: 0.5523, Validation Accuracy: 0.5920, Loss: 0.8789
# Epoch   3 Batch  250/1077 - Train Accuracy: 0.5717, Validation Accuracy: 0.5952, Loss: 0.7924
# Epoch   3 Batch  300/1077 - Train Accuracy: 0.5662, Validation Accuracy: 0.5969, Loss: 0.8746
# Epoch   3 Batch  350/1077 - Train Accuracy: 0.5602, Validation Accuracy: 0.6016, Loss: 0.8802
# Epoch   3 Batch  400/1077 - Train Accuracy: 0.5785, Validation Accuracy: 0.5991, Loss: 0.8391
# Epoch   3 Batch  450/1077 - Train Accuracy: 0.5867, Validation Accuracy: 0.6023, Loss: 0.8347
# Epoch   3 Batch  500/1077 - Train Accuracy: 0.5879, Validation Accuracy: 0.6076, Loss: 0.8160
# Epoch   3 Batch  550/1077 - Train Accuracy: 0.5656, Validation Accuracy: 0.6097, Loss: 0.8549
# Epoch   3 Batch  600/1077 - Train Accuracy: 0.6034, Validation Accuracy: 0.6080, Loss: 0.7782
# Epoch   3 Batch  650/1077 - Train Accuracy: 0.5703, Validation Accuracy: 0.6108, Loss: 0.8374
# Epoch   3 Batch  700/1077 - Train Accuracy: 0.5695, Validation Accuracy: 0.6026, Loss: 0.8001
# Epoch   3 Batch  750/1077 - Train Accuracy: 0.6039, Validation Accuracy: 0.6005, Loss: 0.7986
# Epoch   3 Batch  800/1077 - Train Accuracy: 0.5578, Validation Accuracy: 0.6158, Loss: 0.7955
# Epoch   3 Batch  850/1077 - Train Accuracy: 0.5770, Validation Accuracy: 0.6048, Loss: 0.8312
# Epoch   3 Batch  900/1077 - Train Accuracy: 0.5969, Validation Accuracy: 0.6129, Loss: 0.7936
# Epoch   3 Batch  950/1077 - Train Accuracy: 0.5755, Validation Accuracy: 0.6040, Loss: 0.7763
# Epoch   3 Batch 1000/1077 - Train Accuracy: 0.6269, Validation Accuracy: 0.6129, Loss: 0.7156
# Epoch   3 Batch 1050/1077 - Train Accuracy: 0.5391, Validation Accuracy: 0.6154, Loss: 0.7840
# Epoch   4 Batch   50/1077 - Train Accuracy: 0.5652, Validation Accuracy: 0.6122, Loss: 0.7942
# Epoch   4 Batch  100/1077 - Train Accuracy: 0.6039, Validation Accuracy: 0.6197, Loss: 0.7733
# Epoch   4 Batch  150/1077 - Train Accuracy: 0.6432, Validation Accuracy: 0.6214, Loss: 0.7309
# Epoch   4 Batch  200/1077 - Train Accuracy: 0.5781, Validation Accuracy: 0.6062, Loss: 0.7700
# Epoch   4 Batch  250/1077 - Train Accuracy: 0.5781, Validation Accuracy: 0.6193, Loss: 0.6943
# Epoch   4 Batch  300/1077 - Train Accuracy: 0.6106, Validation Accuracy: 0.6218, Loss: 0.7633
# Epoch   4 Batch  350/1077 - Train Accuracy: 0.5832, Validation Accuracy: 0.6261, Loss: 0.7635
# Epoch   4 Batch  400/1077 - Train Accuracy: 0.6117, Validation Accuracy: 0.6360, Loss: 0.7390
# Epoch   4 Batch  450/1077 - Train Accuracy: 0.6031, Validation Accuracy: 0.6325, Loss: 0.7070
# Epoch   4 Batch  500/1077 - Train Accuracy: 0.6238, Validation Accuracy: 0.6264, Loss: 0.7231
# Epoch   4 Batch  550/1077 - Train Accuracy: 0.5852, Validation Accuracy: 0.6307, Loss: 0.7569
# Epoch   4 Batch  600/1077 - Train Accuracy: 0.6254, Validation Accuracy: 0.6257, Loss: 0.6758
# Epoch   4 Batch  650/1077 - Train Accuracy: 0.5992, Validation Accuracy: 0.6246, Loss: 0.7173
# Epoch   4 Batch  700/1077 - Train Accuracy: 0.6023, Validation Accuracy: 0.6286, Loss: 0.6858
# Epoch   4 Batch  750/1077 - Train Accuracy: 0.6160, Validation Accuracy: 0.6254, Loss: 0.7173
# Epoch   4 Batch  800/1077 - Train Accuracy: 0.5797, Validation Accuracy: 0.6278, Loss: 0.7095
# Epoch   4 Batch  850/1077 - Train Accuracy: 0.5900, Validation Accuracy: 0.6236, Loss: 0.7295
# Epoch   4 Batch  900/1077 - Train Accuracy: 0.6148, Validation Accuracy: 0.6314, Loss: 0.7156
# Epoch   4 Batch  950/1077 - Train Accuracy: 0.5993, Validation Accuracy: 0.6378, Loss: 0.6820
# Epoch   4 Batch 1000/1077 - Train Accuracy: 0.6629, Validation Accuracy: 0.6328, Loss: 0.6353
# Epoch   4 Batch 1050/1077 - Train Accuracy: 0.5641, Validation Accuracy: 0.6328, Loss: 0.7240
# Epoch   5 Batch   50/1077 - Train Accuracy: 0.5871, Validation Accuracy: 0.6417, Loss: 0.7026
# Epoch   5 Batch  100/1077 - Train Accuracy: 0.6262, Validation Accuracy: 0.6378, Loss: 0.6860
# Epoch   5 Batch  150/1077 - Train Accuracy: 0.6469, Validation Accuracy: 0.6406, Loss: 0.6421
# Epoch   5 Batch  200/1077 - Train Accuracy: 0.5949, Validation Accuracy: 0.6186, Loss: 0.6817
# Epoch   5 Batch  250/1077 - Train Accuracy: 0.5945, Validation Accuracy: 0.6456, Loss: 0.6412
# Epoch   5 Batch  300/1077 - Train Accuracy: 0.6184, Validation Accuracy: 0.6428, Loss: 0.6898
# Epoch   5 Batch  350/1077 - Train Accuracy: 0.5871, Validation Accuracy: 0.6481, Loss: 0.6808
# Epoch   5 Batch  400/1077 - Train Accuracy: 0.6352, Validation Accuracy: 0.6460, Loss: 0.6725
# Epoch   5 Batch  450/1077 - Train Accuracy: 0.6289, Validation Accuracy: 0.6406, Loss: 0.6464
# Epoch   5 Batch  500/1077 - Train Accuracy: 0.6535, Validation Accuracy: 0.6491, Loss: 0.6376
# Epoch   5 Batch  550/1077 - Train Accuracy: 0.6039, Validation Accuracy: 0.6460, Loss: 0.6908
# Epoch   5 Batch  600/1077 - Train Accuracy: 0.6451, Validation Accuracy: 0.6374, Loss: 0.6152
# Epoch   5 Batch  650/1077 - Train Accuracy: 0.6102, Validation Accuracy: 0.6538, Loss: 0.6686
# Epoch   5 Batch  700/1077 - Train Accuracy: 0.6027, Validation Accuracy: 0.6552, Loss: 0.6357
# Epoch   5 Batch  750/1077 - Train Accuracy: 0.6375, Validation Accuracy: 0.6580, Loss: 0.6423
# Epoch   5 Batch  800/1077 - Train Accuracy: 0.5984, Validation Accuracy: 0.6541, Loss: 0.6383
# Epoch   5 Batch  850/1077 - Train Accuracy: 0.6116, Validation Accuracy: 0.6502, Loss: 0.6718
# Epoch   5 Batch  900/1077 - Train Accuracy: 0.6367, Validation Accuracy: 0.6545, Loss: 0.6431
# Epoch   5 Batch  950/1077 - Train Accuracy: 0.6068, Validation Accuracy: 0.6559, Loss: 0.6016
# Epoch   5 Batch 1000/1077 - Train Accuracy: 0.6875, Validation Accuracy: 0.6562, Loss: 0.5792
# Epoch   5 Batch 1050/1077 - Train Accuracy: 0.5816, Validation Accuracy: 0.6616, Loss: 0.6442
# Epoch   6 Batch   50/1077 - Train Accuracy: 0.6031, Validation Accuracy: 0.6559, Loss: 0.6448
# Epoch   6 Batch  100/1077 - Train Accuracy: 0.6512, Validation Accuracy: 0.6697, Loss: 0.6187
# Epoch   6 Batch  150/1077 - Train Accuracy: 0.6589, Validation Accuracy: 0.6602, Loss: 0.5807
# Epoch   6 Batch  200/1077 - Train Accuracy: 0.6402, Validation Accuracy: 0.6502, Loss: 0.6227
# Epoch   6 Batch  250/1077 - Train Accuracy: 0.6197, Validation Accuracy: 0.6708, Loss: 0.5691
# Epoch   6 Batch  300/1077 - Train Accuracy: 0.6423, Validation Accuracy: 0.6630, Loss: 0.6232
# Epoch   6 Batch  350/1077 - Train Accuracy: 0.6094, Validation Accuracy: 0.6605, Loss: 0.6300
# Epoch   6 Batch  400/1077 - Train Accuracy: 0.6543, Validation Accuracy: 0.6658, Loss: 0.6254
# Epoch   6 Batch  450/1077 - Train Accuracy: 0.6406, Validation Accuracy: 0.6690, Loss: 0.5867
# Epoch   6 Batch  500/1077 - Train Accuracy: 0.6660, Validation Accuracy: 0.6697, Loss: 0.6022
# Epoch   6 Batch  550/1077 - Train Accuracy: 0.6301, Validation Accuracy: 0.6687, Loss: 0.6262
# Epoch   6 Batch  600/1077 - Train Accuracy: 0.6771, Validation Accuracy: 0.6648, Loss: 0.5655
# Epoch   6 Batch  650/1077 - Train Accuracy: 0.6348, Validation Accuracy: 0.6761, Loss: 0.6125
# Epoch   6 Batch  700/1077 - Train Accuracy: 0.6277, Validation Accuracy: 0.6694, Loss: 0.5685
# Epoch   6 Batch  750/1077 - Train Accuracy: 0.6637, Validation Accuracy: 0.6740, Loss: 0.5812
# Epoch   6 Batch  800/1077 - Train Accuracy: 0.6086, Validation Accuracy: 0.6697, Loss: 0.5979
# Epoch   6 Batch  850/1077 - Train Accuracy: 0.6161, Validation Accuracy: 0.6768, Loss: 0.6403
# Epoch   6 Batch  900/1077 - Train Accuracy: 0.6492, Validation Accuracy: 0.6797, Loss: 0.5939
# Epoch   6 Batch  950/1077 - Train Accuracy: 0.6213, Validation Accuracy: 0.6786, Loss: 0.5683
# Epoch   6 Batch 1000/1077 - Train Accuracy: 0.7061, Validation Accuracy: 0.6829, Loss: 0.5308
# Epoch   6 Batch 1050/1077 - Train Accuracy: 0.6078, Validation Accuracy: 0.6804, Loss: 0.5820
# Epoch   7 Batch   50/1077 - Train Accuracy: 0.6281, Validation Accuracy: 0.6825, Loss: 0.5785
# Epoch   7 Batch  100/1077 - Train Accuracy: 0.6773, Validation Accuracy: 0.6921, Loss: 0.5616
# Epoch   7 Batch  150/1077 - Train Accuracy: 0.6730, Validation Accuracy: 0.6772, Loss: 0.5326
# Epoch   7 Batch  200/1077 - Train Accuracy: 0.6598, Validation Accuracy: 0.6857, Loss: 0.5609
# Epoch   7 Batch  250/1077 - Train Accuracy: 0.6293, Validation Accuracy: 0.6836, Loss: 0.5205
# Epoch   7 Batch  300/1077 - Train Accuracy: 0.6608, Validation Accuracy: 0.6850, Loss: 0.5698
# Epoch   7 Batch  350/1077 - Train Accuracy: 0.6422, Validation Accuracy: 0.6847, Loss: 0.5573
# Epoch   7 Batch  400/1077 - Train Accuracy: 0.6992, Validation Accuracy: 0.7003, Loss: 0.5584
# Epoch   7 Batch  450/1077 - Train Accuracy: 0.6648, Validation Accuracy: 0.6971, Loss: 0.5153
# Epoch   7 Batch  500/1077 - Train Accuracy: 0.6914, Validation Accuracy: 0.6950, Loss: 0.5350
# Epoch   7 Batch  550/1077 - Train Accuracy: 0.6613, Validation Accuracy: 0.6960, Loss: 0.5726
# Epoch   7 Batch  600/1077 - Train Accuracy: 0.6801, Validation Accuracy: 0.6900, Loss: 0.5164
# Epoch   7 Batch  650/1077 - Train Accuracy: 0.6734, Validation Accuracy: 0.7049, Loss: 0.5355
# Epoch   7 Batch  700/1077 - Train Accuracy: 0.6562, Validation Accuracy: 0.6957, Loss: 0.5218
# Epoch   7 Batch  750/1077 - Train Accuracy: 0.6898, Validation Accuracy: 0.7081, Loss: 0.5354
# Epoch   7 Batch  800/1077 - Train Accuracy: 0.6551, Validation Accuracy: 0.7010, Loss: 0.5304
# Epoch   7 Batch  850/1077 - Train Accuracy: 0.6455, Validation Accuracy: 0.7095, Loss: 0.5633
# Epoch   7 Batch  900/1077 - Train Accuracy: 0.6777, Validation Accuracy: 0.6964, Loss: 0.5244
# Epoch   7 Batch  950/1077 - Train Accuracy: 0.6518, Validation Accuracy: 0.7006, Loss: 0.5061
# Epoch   7 Batch 1000/1077 - Train Accuracy: 0.7281, Validation Accuracy: 0.6960, Loss: 0.4928
# Epoch   7 Batch 1050/1077 - Train Accuracy: 0.6074, Validation Accuracy: 0.7085, Loss: 0.5336
# Epoch   8 Batch   50/1077 - Train Accuracy: 0.6523, Validation Accuracy: 0.6950, Loss: 0.5068
# Epoch   8 Batch  100/1077 - Train Accuracy: 0.7000, Validation Accuracy: 0.7085, Loss: 0.5060
# Epoch   8 Batch  150/1077 - Train Accuracy: 0.6983, Validation Accuracy: 0.7038, Loss: 0.4887
# Epoch   8 Batch  200/1077 - Train Accuracy: 0.6738, Validation Accuracy: 0.7070, Loss: 0.5018
# Epoch   8 Batch  250/1077 - Train Accuracy: 0.6562, Validation Accuracy: 0.6964, Loss: 0.4591
# Epoch   8 Batch  300/1077 - Train Accuracy: 0.6883, Validation Accuracy: 0.7106, Loss: 0.5196
# Epoch   8 Batch  350/1077 - Train Accuracy: 0.6680, Validation Accuracy: 0.7035, Loss: 0.5092
# Epoch   8 Batch  400/1077 - Train Accuracy: 0.7152, Validation Accuracy: 0.7092, Loss: 0.5304
# Epoch   8 Batch  450/1077 - Train Accuracy: 0.6766, Validation Accuracy: 0.7035, Loss: 0.4753
# Epoch   8 Batch  500/1077 - Train Accuracy: 0.7078, Validation Accuracy: 0.7184, Loss: 0.4897
# Epoch   8 Batch  550/1077 - Train Accuracy: 0.6730, Validation Accuracy: 0.6953, Loss: 0.5064
# Epoch   8 Batch  600/1077 - Train Accuracy: 0.7228, Validation Accuracy: 0.7038, Loss: 0.4568
# Epoch   8 Batch  650/1077 - Train Accuracy: 0.6926, Validation Accuracy: 0.7148, Loss: 0.5067
# Epoch   8 Batch  700/1077 - Train Accuracy: 0.6687, Validation Accuracy: 0.7085, Loss: 0.4744
# Epoch   8 Batch  750/1077 - Train Accuracy: 0.7156, Validation Accuracy: 0.7099, Loss: 0.4805
# Epoch   8 Batch  800/1077 - Train Accuracy: 0.6758, Validation Accuracy: 0.7131, Loss: 0.4872
# Epoch   8 Batch  850/1077 - Train Accuracy: 0.6629, Validation Accuracy: 0.7202, Loss: 0.5067
# Epoch   8 Batch  900/1077 - Train Accuracy: 0.6973, Validation Accuracy: 0.7035, Loss: 0.4769
# Epoch   8 Batch  950/1077 - Train Accuracy: 0.6570, Validation Accuracy: 0.6982, Loss: 0.4773
# Epoch   8 Batch 1000/1077 - Train Accuracy: 0.7448, Validation Accuracy: 0.7063, Loss: 0.4489
# Epoch   8 Batch 1050/1077 - Train Accuracy: 0.6207, Validation Accuracy: 0.7056, Loss: 0.4831
# Epoch   9 Batch   50/1077 - Train Accuracy: 0.6785, Validation Accuracy: 0.7088, Loss: 0.4757
# Epoch   9 Batch  100/1077 - Train Accuracy: 0.7301, Validation Accuracy: 0.7241, Loss: 0.4783
# Epoch   9 Batch  150/1077 - Train Accuracy: 0.7031, Validation Accuracy: 0.7063, Loss: 0.4428
# Epoch   9 Batch  200/1077 - Train Accuracy: 0.6789, Validation Accuracy: 0.7202, Loss: 0.4798
# Epoch   9 Batch  250/1077 - Train Accuracy: 0.6729, Validation Accuracy: 0.7099, Loss: 0.4464
# Epoch   9 Batch  300/1077 - Train Accuracy: 0.6813, Validation Accuracy: 0.7223, Loss: 0.4820
# Epoch   9 Batch  350/1077 - Train Accuracy: 0.6809, Validation Accuracy: 0.7195, Loss: 0.4800
# Epoch   9 Batch  400/1077 - Train Accuracy: 0.7289, Validation Accuracy: 0.7163, Loss: 0.4852
# Epoch   9 Batch  450/1077 - Train Accuracy: 0.6934, Validation Accuracy: 0.6942, Loss: 0.4506
# Epoch   9 Batch  500/1077 - Train Accuracy: 0.7234, Validation Accuracy: 0.7241, Loss: 0.4383
# Epoch   9 Batch  550/1077 - Train Accuracy: 0.6898, Validation Accuracy: 0.7113, Loss: 0.4684
# Epoch   9 Batch  600/1077 - Train Accuracy: 0.7210, Validation Accuracy: 0.7227, Loss: 0.4400
# Epoch   9 Batch  650/1077 - Train Accuracy: 0.7133, Validation Accuracy: 0.7298, Loss: 0.4807
# Epoch   9 Batch  700/1077 - Train Accuracy: 0.6840, Validation Accuracy: 0.7131, Loss: 0.4322
# Epoch   9 Batch  750/1077 - Train Accuracy: 0.7160, Validation Accuracy: 0.7379, Loss: 0.4519
# Epoch   9 Batch  800/1077 - Train Accuracy: 0.7055, Validation Accuracy: 0.7340, Loss: 0.4399
# Epoch   9 Batch  850/1077 - Train Accuracy: 0.6789, Validation Accuracy: 0.7216, Loss: 0.4802
# Epoch   9 Batch  900/1077 - Train Accuracy: 0.7500, Validation Accuracy: 0.7482, Loss: 0.4358
# Epoch   9 Batch  950/1077 - Train Accuracy: 0.6916, Validation Accuracy: 0.7362, Loss: 0.4463
# Epoch   9 Batch 1000/1077 - Train Accuracy: 0.7541, Validation Accuracy: 0.7319, Loss: 0.4082
# Epoch   9 Batch 1050/1077 - Train Accuracy: 0.6512, Validation Accuracy: 0.7266, Loss: 0.4497
# Epoch  10 Batch   50/1077 - Train Accuracy: 0.6895, Validation Accuracy: 0.7269, Loss: 0.4374
# Epoch  10 Batch  100/1077 - Train Accuracy: 0.7336, Validation Accuracy: 0.7390, Loss: 0.4343
# Epoch  10 Batch  150/1077 - Train Accuracy: 0.7295, Validation Accuracy: 0.7319, Loss: 0.4227
# Epoch  10 Batch  200/1077 - Train Accuracy: 0.7160, Validation Accuracy: 0.7330, Loss: 0.4458
# Epoch  10 Batch  250/1077 - Train Accuracy: 0.7177, Validation Accuracy: 0.7379, Loss: 0.4133
# Epoch  10 Batch  300/1077 - Train Accuracy: 0.7089, Validation Accuracy: 0.7287, Loss: 0.4459
# Epoch  10 Batch  350/1077 - Train Accuracy: 0.7426, Validation Accuracy: 0.7411, Loss: 0.4446
# Epoch  10 Batch  400/1077 - Train Accuracy: 0.7590, Validation Accuracy: 0.7340, Loss: 0.4488
# Epoch  10 Batch  450/1077 - Train Accuracy: 0.7398, Validation Accuracy: 0.7383, Loss: 0.4291
# Epoch  10 Batch  500/1077 - Train Accuracy: 0.7539, Validation Accuracy: 0.7415, Loss: 0.4159
# Epoch  10 Batch  550/1077 - Train Accuracy: 0.7129, Validation Accuracy: 0.7287, Loss: 0.4516
# Epoch  10 Batch  600/1077 - Train Accuracy: 0.7493, Validation Accuracy: 0.7560, Loss: 0.3982
# Epoch  10 Batch  650/1077 - Train Accuracy: 0.7395, Validation Accuracy: 0.7642, Loss: 0.4342
# Epoch  10 Batch  700/1077 - Train Accuracy: 0.7605, Validation Accuracy: 0.7592, Loss: 0.4047
# Epoch  10 Batch  750/1077 - Train Accuracy: 0.7309, Validation Accuracy: 0.7532, Loss: 0.4178
# Epoch  10 Batch  800/1077 - Train Accuracy: 0.7379, Validation Accuracy: 0.7546, Loss: 0.4239
# Epoch  10 Batch  850/1077 - Train Accuracy: 0.7180, Validation Accuracy: 0.7734, Loss: 0.4453
# Epoch  10 Batch  900/1077 - Train Accuracy: 0.7695, Validation Accuracy: 0.7443, Loss: 0.4336
# Epoch  10 Batch  950/1077 - Train Accuracy: 0.7173, Validation Accuracy: 0.7646, Loss: 0.3969
# Epoch  10 Batch 1000/1077 - Train Accuracy: 0.7965, Validation Accuracy: 0.7511, Loss: 0.3892
# Epoch  10 Batch 1050/1077 - Train Accuracy: 0.6988, Validation Accuracy: 0.7408, Loss: 0.4165
# Epoch  11 Batch   50/1077 - Train Accuracy: 0.7242, Validation Accuracy: 0.7482, Loss: 0.4074
# Epoch  11 Batch  100/1077 - Train Accuracy: 0.7531, Validation Accuracy: 0.7628, Loss: 0.3913
# Epoch  11 Batch  150/1077 - Train Accuracy: 0.7615, Validation Accuracy: 0.7521, Loss: 0.3947
# Epoch  11 Batch  200/1077 - Train Accuracy: 0.7531, Validation Accuracy: 0.7592, Loss: 0.4193
# Epoch  11 Batch  250/1077 - Train Accuracy: 0.7589, Validation Accuracy: 0.7475, Loss: 0.3867
# Epoch  11 Batch  300/1077 - Train Accuracy: 0.7615, Validation Accuracy: 0.7624, Loss: 0.4047
# Epoch  11 Batch  350/1077 - Train Accuracy: 0.7762, Validation Accuracy: 0.7546, Loss: 0.4095
# Epoch  11 Batch  400/1077 - Train Accuracy: 0.7730, Validation Accuracy: 0.7638, Loss: 0.4200
# Epoch  11 Batch  450/1077 - Train Accuracy: 0.7766, Validation Accuracy: 0.7319, Loss: 0.4129
# Epoch  11 Batch  500/1077 - Train Accuracy: 0.7688, Validation Accuracy: 0.7692, Loss: 0.3778
# Epoch  11 Batch  550/1077 - Train Accuracy: 0.7266, Validation Accuracy: 0.7372, Loss: 0.4168
# Epoch  11 Batch  600/1077 - Train Accuracy: 0.7682, Validation Accuracy: 0.7571, Loss: 0.3772
# Epoch  11 Batch  650/1077 - Train Accuracy: 0.7680, Validation Accuracy: 0.7724, Loss: 0.4167
# Epoch  11 Batch  700/1077 - Train Accuracy: 0.7703, Validation Accuracy: 0.7624, Loss: 0.3903
# Epoch  11 Batch  750/1077 - Train Accuracy: 0.7410, Validation Accuracy: 0.7528, Loss: 0.3986
# Epoch  11 Batch  800/1077 - Train Accuracy: 0.7379, Validation Accuracy: 0.7773, Loss: 0.3855
# Epoch  11 Batch  850/1077 - Train Accuracy: 0.7102, Validation Accuracy: 0.7653, Loss: 0.4127
# Epoch  11 Batch  900/1077 - Train Accuracy: 0.7742, Validation Accuracy: 0.7596, Loss: 0.4028
# Epoch  11 Batch  950/1077 - Train Accuracy: 0.7202, Validation Accuracy: 0.7610, Loss: 0.3806
# Epoch  11 Batch 1000/1077 - Train Accuracy: 0.7950, Validation Accuracy: 0.7678, Loss: 0.3590
# Epoch  11 Batch 1050/1077 - Train Accuracy: 0.7320, Validation Accuracy: 0.7521, Loss: 0.3997
# Epoch  12 Batch   50/1077 - Train Accuracy: 0.7695, Validation Accuracy: 0.7745, Loss: 0.3826
# Epoch  12 Batch  100/1077 - Train Accuracy: 0.7770, Validation Accuracy: 0.7702, Loss: 0.3894
# Epoch  12 Batch  150/1077 - Train Accuracy: 0.7831, Validation Accuracy: 0.7589, Loss: 0.3666
# Epoch  12 Batch  200/1077 - Train Accuracy: 0.7531, Validation Accuracy: 0.7638, Loss: 0.3871
# Epoch  12 Batch  250/1077 - Train Accuracy: 0.7791, Validation Accuracy: 0.7873, Loss: 0.3614
# Epoch  12 Batch  300/1077 - Train Accuracy: 0.7767, Validation Accuracy: 0.7670, Loss: 0.3752
# Epoch  12 Batch  350/1077 - Train Accuracy: 0.7688, Validation Accuracy: 0.7653, Loss: 0.3694
# Epoch  12 Batch  400/1077 - Train Accuracy: 0.7766, Validation Accuracy: 0.7798, Loss: 0.3965
# Epoch  12 Batch  450/1077 - Train Accuracy: 0.7812, Validation Accuracy: 0.7521, Loss: 0.3775
# Epoch  12 Batch  500/1077 - Train Accuracy: 0.7582, Validation Accuracy: 0.7713, Loss: 0.3585
# Epoch  12 Batch  550/1077 - Train Accuracy: 0.7461, Validation Accuracy: 0.7688, Loss: 0.4025
# Epoch  12 Batch  600/1077 - Train Accuracy: 0.7757, Validation Accuracy: 0.7717, Loss: 0.3495
# Epoch  12 Batch  650/1077 - Train Accuracy: 0.7586, Validation Accuracy: 0.7724, Loss: 0.3691
# Epoch  12 Batch  700/1077 - Train Accuracy: 0.7695, Validation Accuracy: 0.7571, Loss: 0.3545
# Epoch  12 Batch  750/1077 - Train Accuracy: 0.7637, Validation Accuracy: 0.7521, Loss: 0.3859
# Epoch  12 Batch  800/1077 - Train Accuracy: 0.7750, Validation Accuracy: 0.7834, Loss: 0.3704
# Epoch  12 Batch  850/1077 - Train Accuracy: 0.7251, Validation Accuracy: 0.7805, Loss: 0.4111
# Epoch  12 Batch  900/1077 - Train Accuracy: 0.7609, Validation Accuracy: 0.7678, Loss: 0.3745
# Epoch  12 Batch  950/1077 - Train Accuracy: 0.7288, Validation Accuracy: 0.7749, Loss: 0.3614
# Epoch  12 Batch 1000/1077 - Train Accuracy: 0.7887, Validation Accuracy: 0.7827, Loss: 0.3408
# Epoch  12 Batch 1050/1077 - Train Accuracy: 0.7305, Validation Accuracy: 0.7734, Loss: 0.3872
# Epoch  13 Batch   50/1077 - Train Accuracy: 0.7727, Validation Accuracy: 0.7734, Loss: 0.3755
# Epoch  13 Batch  100/1077 - Train Accuracy: 0.7594, Validation Accuracy: 0.7852, Loss: 0.3654
# Epoch  13 Batch  150/1077 - Train Accuracy: 0.7697, Validation Accuracy: 0.7724, Loss: 0.3594
# Epoch  13 Batch  200/1077 - Train Accuracy: 0.7656, Validation Accuracy: 0.7827, Loss: 0.3691
# Epoch  13 Batch  250/1077 - Train Accuracy: 0.7759, Validation Accuracy: 0.7699, Loss: 0.3591
# Epoch  13 Batch  300/1077 - Train Accuracy: 0.7858, Validation Accuracy: 0.7844, Loss: 0.3633
# Epoch  13 Batch  350/1077 - Train Accuracy: 0.7895, Validation Accuracy: 0.7706, Loss: 0.3534
# Epoch  13 Batch  400/1077 - Train Accuracy: 0.7895, Validation Accuracy: 0.7738, Loss: 0.3776
# Epoch  13 Batch  450/1077 - Train Accuracy: 0.7953, Validation Accuracy: 0.7567, Loss: 0.3563
# Epoch  13 Batch  500/1077 - Train Accuracy: 0.7848, Validation Accuracy: 0.7848, Loss: 0.3328
# Epoch  13 Batch  550/1077 - Train Accuracy: 0.7461, Validation Accuracy: 0.7695, Loss: 0.3823
# Epoch  13 Batch  600/1077 - Train Accuracy: 0.7790, Validation Accuracy: 0.7784, Loss: 0.3450
# Epoch  13 Batch  650/1077 - Train Accuracy: 0.7555, Validation Accuracy: 0.7770, Loss: 0.3671
# Epoch  13 Batch  700/1077 - Train Accuracy: 0.7711, Validation Accuracy: 0.7788, Loss: 0.3539
# Epoch  13 Batch  750/1077 - Train Accuracy: 0.7695, Validation Accuracy: 0.7710, Loss: 0.3664
# Epoch  13 Batch  800/1077 - Train Accuracy: 0.7824, Validation Accuracy: 0.7702, Loss: 0.3494
# Epoch  13 Batch  850/1077 - Train Accuracy: 0.7366, Validation Accuracy: 0.7727, Loss: 0.4003
# Epoch  13 Batch  900/1077 - Train Accuracy: 0.7676, Validation Accuracy: 0.7695, Loss: 0.3571
# Epoch  13 Batch  950/1077 - Train Accuracy: 0.7400, Validation Accuracy: 0.7741, Loss: 0.3599
# Epoch  13 Batch 1000/1077 - Train Accuracy: 0.7917, Validation Accuracy: 0.7777, Loss: 0.3249
# Epoch  13 Batch 1050/1077 - Train Accuracy: 0.7438, Validation Accuracy: 0.7812, Loss: 0.3660
# Epoch  14 Batch   50/1077 - Train Accuracy: 0.7715, Validation Accuracy: 0.7784, Loss: 0.3567
# Epoch  14 Batch  100/1077 - Train Accuracy: 0.7652, Validation Accuracy: 0.7848, Loss: 0.3511
# Epoch  14 Batch  150/1077 - Train Accuracy: 0.7749, Validation Accuracy: 0.7642, Loss: 0.3342
# Epoch  14 Batch  200/1077 - Train Accuracy: 0.7641, Validation Accuracy: 0.7823, Loss: 0.3473
# Epoch  14 Batch  250/1077 - Train Accuracy: 0.7887, Validation Accuracy: 0.7734, Loss: 0.3348
# Epoch  14 Batch  300/1077 - Train Accuracy: 0.8035, Validation Accuracy: 0.7773, Loss: 0.3317
# Epoch  14 Batch  350/1077 - Train Accuracy: 0.7992, Validation Accuracy: 0.7678, Loss: 0.3562
# Epoch  14 Batch  400/1077 - Train Accuracy: 0.8020, Validation Accuracy: 0.7837, Loss: 0.3740
# Epoch  14 Batch  450/1077 - Train Accuracy: 0.8008, Validation Accuracy: 0.7770, Loss: 0.3533
# Epoch  14 Batch  500/1077 - Train Accuracy: 0.7754, Validation Accuracy: 0.7791, Loss: 0.3289
# Epoch  14 Batch  550/1077 - Train Accuracy: 0.7363, Validation Accuracy: 0.7805, Loss: 0.3580
# Epoch  14 Batch  600/1077 - Train Accuracy: 0.7794, Validation Accuracy: 0.7763, Loss: 0.3208
# Epoch  14 Batch  650/1077 - Train Accuracy: 0.7539, Validation Accuracy: 0.7976, Loss: 0.3708
# Epoch  14 Batch  700/1077 - Train Accuracy: 0.7758, Validation Accuracy: 0.7802, Loss: 0.3324
# Epoch  14 Batch  750/1077 - Train Accuracy: 0.7836, Validation Accuracy: 0.7844, Loss: 0.3306
# Epoch  14 Batch  800/1077 - Train Accuracy: 0.7926, Validation Accuracy: 0.7834, Loss: 0.3365
# Epoch  14 Batch  850/1077 - Train Accuracy: 0.7429, Validation Accuracy: 0.7795, Loss: 0.3762
# Epoch  14 Batch  900/1077 - Train Accuracy: 0.7762, Validation Accuracy: 0.7784, Loss: 0.3356
# Epoch  14 Batch  950/1077 - Train Accuracy: 0.7519, Validation Accuracy: 0.7724, Loss: 0.3217
# Epoch  14 Batch 1000/1077 - Train Accuracy: 0.7935, Validation Accuracy: 0.7809, Loss: 0.3089
# Epoch  14 Batch 1050/1077 - Train Accuracy: 0.7457, Validation Accuracy: 0.7844, Loss: 0.3583
# Epoch  15 Batch   50/1077 - Train Accuracy: 0.7754, Validation Accuracy: 0.7802, Loss: 0.3320
# Epoch  15 Batch  100/1077 - Train Accuracy: 0.7621, Validation Accuracy: 0.7884, Loss: 0.3405
# Epoch  15 Batch  150/1077 - Train Accuracy: 0.7742, Validation Accuracy: 0.7766, Loss: 0.3325
# Epoch  15 Batch  200/1077 - Train Accuracy: 0.7461, Validation Accuracy: 0.7788, Loss: 0.3167
# Epoch  15 Batch  250/1077 - Train Accuracy: 0.7930, Validation Accuracy: 0.7773, Loss: 0.3135
# Epoch  15 Batch  300/1077 - Train Accuracy: 0.8129, Validation Accuracy: 0.7898, Loss: 0.3255
# Epoch  15 Batch  350/1077 - Train Accuracy: 0.8059, Validation Accuracy: 0.7891, Loss: 0.3382
# Epoch  15 Batch  400/1077 - Train Accuracy: 0.7988, Validation Accuracy: 0.7951, Loss: 0.3563
# Epoch  15 Batch  450/1077 - Train Accuracy: 0.7922, Validation Accuracy: 0.7781, Loss: 0.3232
# Epoch  15 Batch  500/1077 - Train Accuracy: 0.7762, Validation Accuracy: 0.7994, Loss: 0.3080
# Epoch  15 Batch  550/1077 - Train Accuracy: 0.7406, Validation Accuracy: 0.7923, Loss: 0.3553
# Epoch  15 Batch  600/1077 - Train Accuracy: 0.7950, Validation Accuracy: 0.7937, Loss: 0.3219
# Epoch  15 Batch  650/1077 - Train Accuracy: 0.7824, Validation Accuracy: 0.7894, Loss: 0.3317
# Epoch  15 Batch  700/1077 - Train Accuracy: 0.7766, Validation Accuracy: 0.7667, Loss: 0.3224
# Epoch  15 Batch  750/1077 - Train Accuracy: 0.7902, Validation Accuracy: 0.7766, Loss: 0.3392
# Epoch  15 Batch  800/1077 - Train Accuracy: 0.7918, Validation Accuracy: 0.7820, Loss: 0.3292
# Epoch  15 Batch  850/1077 - Train Accuracy: 0.7437, Validation Accuracy: 0.7802, Loss: 0.3527
# Epoch  15 Batch  900/1077 - Train Accuracy: 0.8098, Validation Accuracy: 0.7848, Loss: 0.3337
# Epoch  15 Batch  950/1077 - Train Accuracy: 0.7671, Validation Accuracy: 0.7901, Loss: 0.3170
# Epoch  15 Batch 1000/1077 - Train Accuracy: 0.7946, Validation Accuracy: 0.7898, Loss: 0.2930
# Epoch  15 Batch 1050/1077 - Train Accuracy: 0.7453, Validation Accuracy: 0.7908, Loss: 0.3237
# Epoch  16 Batch   50/1077 - Train Accuracy: 0.7641, Validation Accuracy: 0.7795, Loss: 0.3348
# Epoch  16 Batch  100/1077 - Train Accuracy: 0.7750, Validation Accuracy: 0.7724, Loss: 0.3140
# Epoch  16 Batch  150/1077 - Train Accuracy: 0.7868, Validation Accuracy: 0.7791, Loss: 0.3159
# Epoch  16 Batch  200/1077 - Train Accuracy: 0.7594, Validation Accuracy: 0.7660, Loss: 0.3163
# Epoch  16 Batch  250/1077 - Train Accuracy: 0.7894, Validation Accuracy: 0.7873, Loss: 0.2900
# Epoch  16 Batch  300/1077 - Train Accuracy: 0.8158, Validation Accuracy: 0.7852, Loss: 0.3065
# Epoch  16 Batch  350/1077 - Train Accuracy: 0.8008, Validation Accuracy: 0.7852, Loss: 0.3116
# Epoch  16 Batch  400/1077 - Train Accuracy: 0.8074, Validation Accuracy: 0.7841, Loss: 0.3499
# Epoch  16 Batch  450/1077 - Train Accuracy: 0.8277, Validation Accuracy: 0.7738, Loss: 0.3180
# Epoch  16 Batch  500/1077 - Train Accuracy: 0.7781, Validation Accuracy: 0.7848, Loss: 0.2945
# Epoch  16 Batch  550/1077 - Train Accuracy: 0.7648, Validation Accuracy: 0.7969, Loss: 0.3311
# Epoch  16 Batch  600/1077 - Train Accuracy: 0.7939, Validation Accuracy: 0.7784, Loss: 0.3085
# Epoch  16 Batch  650/1077 - Train Accuracy: 0.7848, Validation Accuracy: 0.7834, Loss: 0.3163
# Epoch  16 Batch  700/1077 - Train Accuracy: 0.8094, Validation Accuracy: 0.7972, Loss: 0.2890
# Epoch  16 Batch  750/1077 - Train Accuracy: 0.8016, Validation Accuracy: 0.7962, Loss: 0.3160
# Epoch  16 Batch  800/1077 - Train Accuracy: 0.8000, Validation Accuracy: 0.7983, Loss: 0.2992
# Epoch  16 Batch  850/1077 - Train Accuracy: 0.7515, Validation Accuracy: 0.7844, Loss: 0.3470
# Epoch  16 Batch  900/1077 - Train Accuracy: 0.8168, Validation Accuracy: 0.7891, Loss: 0.3196
# Epoch  16 Batch  950/1077 - Train Accuracy: 0.7333, Validation Accuracy: 0.7763, Loss: 0.2845
# Epoch  16 Batch 1000/1077 - Train Accuracy: 0.8069, Validation Accuracy: 0.7827, Loss: 0.2638
# Epoch  16 Batch 1050/1077 - Train Accuracy: 0.7414, Validation Accuracy: 0.7933, Loss: 0.3161
# Epoch  17 Batch   50/1077 - Train Accuracy: 0.7977, Validation Accuracy: 0.7979, Loss: 0.3051
# Epoch  17 Batch  100/1077 - Train Accuracy: 0.7793, Validation Accuracy: 0.7947, Loss: 0.2955
# Epoch  17 Batch  150/1077 - Train Accuracy: 0.8103, Validation Accuracy: 0.7951, Loss: 0.3000
# Epoch  17 Batch  200/1077 - Train Accuracy: 0.7766, Validation Accuracy: 0.8068, Loss: 0.3044
# Epoch  17 Batch  250/1077 - Train Accuracy: 0.8026, Validation Accuracy: 0.7951, Loss: 0.2861
# Epoch  17 Batch  300/1077 - Train Accuracy: 0.8261, Validation Accuracy: 0.7994, Loss: 0.2969
# Epoch  17 Batch  350/1077 - Train Accuracy: 0.8164, Validation Accuracy: 0.8036, Loss: 0.2983
# Epoch  17 Batch  400/1077 - Train Accuracy: 0.8242, Validation Accuracy: 0.7795, Loss: 0.3286
# Epoch  17 Batch  450/1077 - Train Accuracy: 0.8129, Validation Accuracy: 0.7969, Loss: 0.3124
# Epoch  17 Batch  500/1077 - Train Accuracy: 0.7902, Validation Accuracy: 0.8089, Loss: 0.2834
# Epoch  17 Batch  550/1077 - Train Accuracy: 0.7668, Validation Accuracy: 0.7873, Loss: 0.3211
# Epoch  17 Batch  600/1077 - Train Accuracy: 0.8177, Validation Accuracy: 0.8018, Loss: 0.2869
# Epoch  17 Batch  650/1077 - Train Accuracy: 0.8000, Validation Accuracy: 0.7901, Loss: 0.3391
# Epoch  17 Batch  700/1077 - Train Accuracy: 0.8051, Validation Accuracy: 0.7979, Loss: 0.2908
# Epoch  17 Batch  750/1077 - Train Accuracy: 0.8176, Validation Accuracy: 0.7937, Loss: 0.3170
# Epoch  17 Batch  800/1077 - Train Accuracy: 0.8223, Validation Accuracy: 0.8143, Loss: 0.2969
# Epoch  17 Batch  850/1077 - Train Accuracy: 0.7693, Validation Accuracy: 0.8001, Loss: 0.3328
# Epoch  17 Batch  900/1077 - Train Accuracy: 0.7883, Validation Accuracy: 0.7972, Loss: 0.3190
# Epoch  17 Batch  950/1077 - Train Accuracy: 0.7664, Validation Accuracy: 0.7976, Loss: 0.2881
# Epoch  17 Batch 1000/1077 - Train Accuracy: 0.8144, Validation Accuracy: 0.8121, Loss: 0.2672
# Epoch  17 Batch 1050/1077 - Train Accuracy: 0.7590, Validation Accuracy: 0.7990, Loss: 0.3125
# Epoch  18 Batch   50/1077 - Train Accuracy: 0.8066, Validation Accuracy: 0.8068, Loss: 0.2984
# Epoch  18 Batch  100/1077 - Train Accuracy: 0.7801, Validation Accuracy: 0.7955, Loss: 0.2893
# Epoch  18 Batch  150/1077 - Train Accuracy: 0.8054, Validation Accuracy: 0.7908, Loss: 0.2896
# Epoch  18 Batch  200/1077 - Train Accuracy: 0.7852, Validation Accuracy: 0.8026, Loss: 0.2947
# Epoch  18 Batch  250/1077 - Train Accuracy: 0.8118, Validation Accuracy: 0.7887, Loss: 0.2559
# Epoch  18 Batch  300/1077 - Train Accuracy: 0.8450, Validation Accuracy: 0.7951, Loss: 0.2959
# Epoch  18 Batch  350/1077 - Train Accuracy: 0.8187, Validation Accuracy: 0.7990, Loss: 0.2798
# Epoch  18 Batch  400/1077 - Train Accuracy: 0.8461, Validation Accuracy: 0.7962, Loss: 0.3160
# Epoch  18 Batch  450/1077 - Train Accuracy: 0.8090, Validation Accuracy: 0.8015, Loss: 0.2943
# Epoch  18 Batch  500/1077 - Train Accuracy: 0.7945, Validation Accuracy: 0.8114, Loss: 0.2773
# Epoch  18 Batch  550/1077 - Train Accuracy: 0.7613, Validation Accuracy: 0.8082, Loss: 0.3021
# Epoch  18 Batch  600/1077 - Train Accuracy: 0.8162, Validation Accuracy: 0.8125, Loss: 0.2733
# Epoch  18 Batch  650/1077 - Train Accuracy: 0.8090, Validation Accuracy: 0.8047, Loss: 0.2978
# Epoch  18 Batch  700/1077 - Train Accuracy: 0.8129, Validation Accuracy: 0.7972, Loss: 0.2675
# Epoch  18 Batch  750/1077 - Train Accuracy: 0.8348, Validation Accuracy: 0.8100, Loss: 0.2941
# Epoch  18 Batch  800/1077 - Train Accuracy: 0.8293, Validation Accuracy: 0.8146, Loss: 0.2744
# Epoch  18 Batch  850/1077 - Train Accuracy: 0.7649, Validation Accuracy: 0.8068, Loss: 0.3226
# Epoch  18 Batch  900/1077 - Train Accuracy: 0.8133, Validation Accuracy: 0.8043, Loss: 0.2935
# Epoch  18 Batch  950/1077 - Train Accuracy: 0.7913, Validation Accuracy: 0.8022, Loss: 0.2742
# Epoch  18 Batch 1000/1077 - Train Accuracy: 0.8270, Validation Accuracy: 0.8171, Loss: 0.2612
# Epoch  18 Batch 1050/1077 - Train Accuracy: 0.7609, Validation Accuracy: 0.8114, Loss: 0.2806
# Epoch  19 Batch   50/1077 - Train Accuracy: 0.8047, Validation Accuracy: 0.8065, Loss: 0.2773
# Epoch  19 Batch  100/1077 - Train Accuracy: 0.7914, Validation Accuracy: 0.8058, Loss: 0.2758
# Epoch  19 Batch  150/1077 - Train Accuracy: 0.8367, Validation Accuracy: 0.8121, Loss: 0.2798
# Epoch  19 Batch  200/1077 - Train Accuracy: 0.7918, Validation Accuracy: 0.8001, Loss: 0.2793
# Epoch  19 Batch  250/1077 - Train Accuracy: 0.8150, Validation Accuracy: 0.8111, Loss: 0.2604
# Epoch  19 Batch  300/1077 - Train Accuracy: 0.8355, Validation Accuracy: 0.8175, Loss: 0.2730
# Epoch  19 Batch  350/1077 - Train Accuracy: 0.8508, Validation Accuracy: 0.8136, Loss: 0.2792
# Epoch  19 Batch  400/1077 - Train Accuracy: 0.8379, Validation Accuracy: 0.8100, Loss: 0.3052
# Epoch  19 Batch  450/1077 - Train Accuracy: 0.8387, Validation Accuracy: 0.8001, Loss: 0.2674
# Epoch  19 Batch  500/1077 - Train Accuracy: 0.8367, Validation Accuracy: 0.8317, Loss: 0.2587
# Epoch  19 Batch  550/1077 - Train Accuracy: 0.7855, Validation Accuracy: 0.8324, Loss: 0.3015
# Epoch  19 Batch  600/1077 - Train Accuracy: 0.8337, Validation Accuracy: 0.8207, Loss: 0.2651
# Epoch  19 Batch  650/1077 - Train Accuracy: 0.8344, Validation Accuracy: 0.8015, Loss: 0.3035
# Epoch  19 Batch  700/1077 - Train Accuracy: 0.8051, Validation Accuracy: 0.8061, Loss: 0.2640
# Epoch  19 Batch  750/1077 - Train Accuracy: 0.8496, Validation Accuracy: 0.8132, Loss: 0.2846
# Epoch  19 Batch  800/1077 - Train Accuracy: 0.8344, Validation Accuracy: 0.8239, Loss: 0.2586
# Epoch  19 Batch  850/1077 - Train Accuracy: 0.7920, Validation Accuracy: 0.8263, Loss: 0.2983
# Epoch  19 Batch  900/1077 - Train Accuracy: 0.8449, Validation Accuracy: 0.8040, Loss: 0.2755
# Epoch  19 Batch  950/1077 - Train Accuracy: 0.8132, Validation Accuracy: 0.8192, Loss: 0.2627
# Epoch  19 Batch 1000/1077 - Train Accuracy: 0.8337, Validation Accuracy: 0.8207, Loss: 0.2307
# Epoch  19 Batch 1050/1077 - Train Accuracy: 0.8066, Validation Accuracy: 0.8182, Loss: 0.2783
# Epoch  20 Batch   50/1077 - Train Accuracy: 0.8004, Validation Accuracy: 0.8058, Loss: 0.2624
# Epoch  20 Batch  100/1077 - Train Accuracy: 0.8129, Validation Accuracy: 0.8072, Loss: 0.2574
# Epoch  20 Batch  150/1077 - Train Accuracy: 0.8683, Validation Accuracy: 0.8121, Loss: 0.2410
# Epoch  20 Batch  200/1077 - Train Accuracy: 0.8211, Validation Accuracy: 0.8221, Loss: 0.2710
# Epoch  20 Batch  250/1077 - Train Accuracy: 0.8246, Validation Accuracy: 0.7979, Loss: 0.2580
# Epoch  20 Batch  300/1077 - Train Accuracy: 0.8635, Validation Accuracy: 0.8303, Loss: 0.2458
# Epoch  20 Batch  350/1077 - Train Accuracy: 0.8664, Validation Accuracy: 0.8175, Loss: 0.2487
# Epoch  20 Batch  400/1077 - Train Accuracy: 0.8313, Validation Accuracy: 0.8256, Loss: 0.2759
# Epoch  20 Batch  450/1077 - Train Accuracy: 0.8473, Validation Accuracy: 0.8043, Loss: 0.2471
# Epoch  20 Batch  500/1077 - Train Accuracy: 0.8434, Validation Accuracy: 0.8445, Loss: 0.2571
# Epoch  20 Batch  550/1077 - Train Accuracy: 0.8051, Validation Accuracy: 0.8253, Loss: 0.2720
# Epoch  20 Batch  600/1077 - Train Accuracy: 0.8389, Validation Accuracy: 0.8118, Loss: 0.2525
# Epoch  20 Batch  650/1077 - Train Accuracy: 0.8418, Validation Accuracy: 0.8242, Loss: 0.2714
# Epoch  20 Batch  700/1077 - Train Accuracy: 0.8707, Validation Accuracy: 0.8125, Loss: 0.2392
# Epoch  20 Batch  750/1077 - Train Accuracy: 0.8629, Validation Accuracy: 0.8150, Loss: 0.2600
# Epoch  20 Batch  800/1077 - Train Accuracy: 0.8539, Validation Accuracy: 0.8313, Loss: 0.2517
# Epoch  20 Batch  850/1077 - Train Accuracy: 0.8118, Validation Accuracy: 0.8441, Loss: 0.2932
# Epoch  20 Batch  900/1077 - Train Accuracy: 0.8512, Validation Accuracy: 0.8217, Loss: 0.2616
# Epoch  20 Batch  950/1077 - Train Accuracy: 0.8144, Validation Accuracy: 0.8153, Loss: 0.2493
# Epoch  20 Batch 1000/1077 - Train Accuracy: 0.8512, Validation Accuracy: 0.8260, Loss: 0.2269
# Epoch  20 Batch 1050/1077 - Train Accuracy: 0.8109, Validation Accuracy: 0.8267, Loss: 0.2541
# Epoch  21 Batch   50/1077 - Train Accuracy: 0.8746, Validation Accuracy: 0.8278, Loss: 0.2599
# Epoch  21 Batch  100/1077 - Train Accuracy: 0.8207, Validation Accuracy: 0.8523, Loss: 0.2419
# Epoch  21 Batch  150/1077 - Train Accuracy: 0.8672, Validation Accuracy: 0.8200, Loss: 0.2428
# Epoch  21 Batch  200/1077 - Train Accuracy: 0.8219, Validation Accuracy: 0.8469, Loss: 0.2618
# Epoch  21 Batch  250/1077 - Train Accuracy: 0.8391, Validation Accuracy: 0.8299, Loss: 0.2390
# Epoch  21 Batch  300/1077 - Train Accuracy: 0.8914, Validation Accuracy: 0.8512, Loss: 0.2485
# Epoch  21 Batch  350/1077 - Train Accuracy: 0.8883, Validation Accuracy: 0.8359, Loss: 0.2444
# Epoch  21 Batch  400/1077 - Train Accuracy: 0.8543, Validation Accuracy: 0.8303, Loss: 0.2675
# Epoch  21 Batch  450/1077 - Train Accuracy: 0.8508, Validation Accuracy: 0.8068, Loss: 0.2383
# Epoch  21 Batch  500/1077 - Train Accuracy: 0.8633, Validation Accuracy: 0.8434, Loss: 0.2279
# Epoch  21 Batch  550/1077 - Train Accuracy: 0.8199, Validation Accuracy: 0.8523, Loss: 0.2685
# Epoch  21 Batch  600/1077 - Train Accuracy: 0.8612, Validation Accuracy: 0.8565, Loss: 0.2342
# Epoch  21 Batch  650/1077 - Train Accuracy: 0.8453, Validation Accuracy: 0.8487, Loss: 0.2537
# Epoch  21 Batch  700/1077 - Train Accuracy: 0.8625, Validation Accuracy: 0.8420, Loss: 0.2475
# Epoch  21 Batch  750/1077 - Train Accuracy: 0.8508, Validation Accuracy: 0.8292, Loss: 0.2645
# Epoch  21 Batch  800/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8590, Loss: 0.2470
# Epoch  21 Batch  850/1077 - Train Accuracy: 0.8330, Validation Accuracy: 0.8466, Loss: 0.2859
# Epoch  21 Batch  900/1077 - Train Accuracy: 0.8605, Validation Accuracy: 0.8349, Loss: 0.2428
# Epoch  21 Batch  950/1077 - Train Accuracy: 0.8374, Validation Accuracy: 0.8374, Loss: 0.2414
# Epoch  21 Batch 1000/1077 - Train Accuracy: 0.8583, Validation Accuracy: 0.8498, Loss: 0.2182
# Epoch  21 Batch 1050/1077 - Train Accuracy: 0.8371, Validation Accuracy: 0.8224, Loss: 0.2426
# Epoch  22 Batch   50/1077 - Train Accuracy: 0.8715, Validation Accuracy: 0.8388, Loss: 0.2464
# Epoch  22 Batch  100/1077 - Train Accuracy: 0.8539, Validation Accuracy: 0.8416, Loss: 0.2371
# Epoch  22 Batch  150/1077 - Train Accuracy: 0.8810, Validation Accuracy: 0.8512, Loss: 0.2336
# Epoch  22 Batch  200/1077 - Train Accuracy: 0.8305, Validation Accuracy: 0.8455, Loss: 0.2443
# Epoch  22 Batch  250/1077 - Train Accuracy: 0.8619, Validation Accuracy: 0.8228, Loss: 0.2227
# Epoch  22 Batch  300/1077 - Train Accuracy: 0.8997, Validation Accuracy: 0.8441, Loss: 0.2483
# Epoch  22 Batch  350/1077 - Train Accuracy: 0.8855, Validation Accuracy: 0.8512, Loss: 0.2459
# Epoch  22 Batch  400/1077 - Train Accuracy: 0.8648, Validation Accuracy: 0.8381, Loss: 0.2521
# Epoch  22 Batch  450/1077 - Train Accuracy: 0.8844, Validation Accuracy: 0.8452, Loss: 0.2438
# Epoch  22 Batch  500/1077 - Train Accuracy: 0.8801, Validation Accuracy: 0.8484, Loss: 0.2117
# Epoch  22 Batch  550/1077 - Train Accuracy: 0.8289, Validation Accuracy: 0.8484, Loss: 0.2421
# Epoch  22 Batch  600/1077 - Train Accuracy: 0.8531, Validation Accuracy: 0.8285, Loss: 0.2291
# Epoch  22 Batch  650/1077 - Train Accuracy: 0.8633, Validation Accuracy: 0.8366, Loss: 0.2503
# Epoch  22 Batch  700/1077 - Train Accuracy: 0.8852, Validation Accuracy: 0.8359, Loss: 0.2215
# Epoch  22 Batch  750/1077 - Train Accuracy: 0.8645, Validation Accuracy: 0.8331, Loss: 0.2559
# Epoch  22 Batch  800/1077 - Train Accuracy: 0.8770, Validation Accuracy: 0.8487, Loss: 0.2272
# Epoch  22 Batch  850/1077 - Train Accuracy: 0.8512, Validation Accuracy: 0.8555, Loss: 0.2484
# Epoch  22 Batch  900/1077 - Train Accuracy: 0.8500, Validation Accuracy: 0.8597, Loss: 0.2446
# Epoch  22 Batch  950/1077 - Train Accuracy: 0.8571, Validation Accuracy: 0.8487, Loss: 0.2176
# Epoch  22 Batch 1000/1077 - Train Accuracy: 0.8783, Validation Accuracy: 0.8487, Loss: 0.2161
# Epoch  22 Batch 1050/1077 - Train Accuracy: 0.8430, Validation Accuracy: 0.8654, Loss: 0.2384
# Epoch  23 Batch   50/1077 - Train Accuracy: 0.8867, Validation Accuracy: 0.8388, Loss: 0.2329
# Epoch  23 Batch  100/1077 - Train Accuracy: 0.8539, Validation Accuracy: 0.8398, Loss: 0.2208
# Epoch  23 Batch  150/1077 - Train Accuracy: 0.8824, Validation Accuracy: 0.8395, Loss: 0.2235
# Epoch  23 Batch  200/1077 - Train Accuracy: 0.8297, Validation Accuracy: 0.8501, Loss: 0.2288
# Epoch  23 Batch  250/1077 - Train Accuracy: 0.8640, Validation Accuracy: 0.8384, Loss: 0.2177
# Epoch  23 Batch  300/1077 - Train Accuracy: 0.9021, Validation Accuracy: 0.8423, Loss: 0.2292
# Epoch  23 Batch  350/1077 - Train Accuracy: 0.8746, Validation Accuracy: 0.8604, Loss: 0.2228
# Epoch  23 Batch  400/1077 - Train Accuracy: 0.8625, Validation Accuracy: 0.8477, Loss: 0.2539
# Epoch  23 Batch  450/1077 - Train Accuracy: 0.8844, Validation Accuracy: 0.8271, Loss: 0.2418
# Epoch  23 Batch  500/1077 - Train Accuracy: 0.8781, Validation Accuracy: 0.8516, Loss: 0.2164
# Epoch  23 Batch  550/1077 - Train Accuracy: 0.8215, Validation Accuracy: 0.8654, Loss: 0.2443
# Epoch  23 Batch  600/1077 - Train Accuracy: 0.8672, Validation Accuracy: 0.8555, Loss: 0.2213
# Epoch  23 Batch  650/1077 - Train Accuracy: 0.8711, Validation Accuracy: 0.8558, Loss: 0.2417
# Epoch  23 Batch  700/1077 - Train Accuracy: 0.8840, Validation Accuracy: 0.8530, Loss: 0.2140
# Epoch  23 Batch  750/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8466, Loss: 0.2318
# Epoch  23 Batch  800/1077 - Train Accuracy: 0.8867, Validation Accuracy: 0.8558, Loss: 0.2239
# Epoch  23 Batch  850/1077 - Train Accuracy: 0.8490, Validation Accuracy: 0.8661, Loss: 0.2546
# Epoch  23 Batch  900/1077 - Train Accuracy: 0.8664, Validation Accuracy: 0.8697, Loss: 0.2395
# Epoch  23 Batch  950/1077 - Train Accuracy: 0.8597, Validation Accuracy: 0.8651, Loss: 0.2171
# Epoch  23 Batch 1000/1077 - Train Accuracy: 0.8579, Validation Accuracy: 0.8473, Loss: 0.1921
# Epoch  23 Batch 1050/1077 - Train Accuracy: 0.8566, Validation Accuracy: 0.8565, Loss: 0.2159
# Epoch  24 Batch   50/1077 - Train Accuracy: 0.8660, Validation Accuracy: 0.8633, Loss: 0.2135
# Epoch  24 Batch  100/1077 - Train Accuracy: 0.8477, Validation Accuracy: 0.8366, Loss: 0.2137
# Epoch  24 Batch  150/1077 - Train Accuracy: 0.8832, Validation Accuracy: 0.8558, Loss: 0.2126
# Epoch  24 Batch  200/1077 - Train Accuracy: 0.8363, Validation Accuracy: 0.8441, Loss: 0.2317
# Epoch  24 Batch  250/1077 - Train Accuracy: 0.8793, Validation Accuracy: 0.8491, Loss: 0.2164
# Epoch  24 Batch  300/1077 - Train Accuracy: 0.8972, Validation Accuracy: 0.8615, Loss: 0.2094
# ...
# Epoch  51 Batch 1050/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9094, Loss: 0.1174
# Epoch  52 Batch   50/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.9109, Loss: 0.1257
# Epoch  52 Batch  100/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.9222, Loss: 0.1262
# Epoch  52 Batch  150/1077 - Train Accuracy: 0.9167, Validation Accuracy: 0.9055, Loss: 0.1212
# Epoch  52 Batch  200/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.9048, Loss: 0.1486
# Epoch  52 Batch  250/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9105, Loss: 0.1228
# Epoch  52 Batch  300/1077 - Train Accuracy: 0.9552, Validation Accuracy: 0.9094, Loss: 0.1078
# Epoch  52 Batch  350/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.9006, Loss: 0.1259
# Epoch  52 Batch  400/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9038, Loss: 0.1584
# Epoch  52 Batch  450/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.9208, Loss: 0.1405
# Epoch  52 Batch  500/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9194, Loss: 0.1135
# Epoch  52 Batch  550/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.9087, Loss: 0.1421
# Epoch  52 Batch  600/1077 - Train Accuracy: 0.9349, Validation Accuracy: 0.9151, Loss: 0.1330
# Epoch  52 Batch  650/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9123, Loss: 0.1284
# Epoch  52 Batch  700/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9229, Loss: 0.1202
# Epoch  52 Batch  750/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9144, Loss: 0.1381
# Epoch  52 Batch  800/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9315, Loss: 0.1255
# Epoch  52 Batch  850/1077 - Train Accuracy: 0.9122, Validation Accuracy: 0.9137, Loss: 0.1578
# Epoch  52 Batch  900/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.9176, Loss: 0.1590
# Epoch  52 Batch  950/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9141, Loss: 0.1337
# Epoch  52 Batch 1000/1077 - Train Accuracy: 0.9170, Validation Accuracy: 0.9055, Loss: 0.1229
# Epoch  52 Batch 1050/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.9162, Loss: 0.1272
# Epoch  53 Batch   50/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9070, Loss: 0.1301
# Epoch  53 Batch  100/1077 - Train Accuracy: 0.9164, Validation Accuracy: 0.9343, Loss: 0.1211
# Epoch  53 Batch  150/1077 - Train Accuracy: 0.9178, Validation Accuracy: 0.9176, Loss: 0.1296
# Epoch  53 Batch  200/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9137, Loss: 0.1414
# Epoch  53 Batch  250/1077 - Train Accuracy: 0.9322, Validation Accuracy: 0.9194, Loss: 0.1026
# Epoch  53 Batch  300/1077 - Train Accuracy: 0.9667, Validation Accuracy: 0.9222, Loss: 0.1151
# Epoch  53 Batch  350/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9048, Loss: 0.1161
# Epoch  53 Batch  400/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.9141, Loss: 0.1457
# Epoch  53 Batch  450/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9087, Loss: 0.1440
# Epoch  53 Batch  500/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.9123, Loss: 0.1080
# Epoch  53 Batch  550/1077 - Train Accuracy: 0.8828, Validation Accuracy: 0.9102, Loss: 0.1402
# Epoch  53 Batch  600/1077 - Train Accuracy: 0.9412, Validation Accuracy: 0.9283, Loss: 0.1179
# Epoch  53 Batch  650/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9137, Loss: 0.1381
# Epoch  53 Batch  700/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9151, Loss: 0.1142
# Epoch  53 Batch  750/1077 - Train Accuracy: 0.9164, Validation Accuracy: 0.9134, Loss: 0.1340
# Epoch  53 Batch  800/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9187, Loss: 0.1128
# Epoch  53 Batch  850/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.9109, Loss: 0.1555
# Epoch  53 Batch  900/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.9123, Loss: 0.1426
# Epoch  53 Batch  950/1077 - Train Accuracy: 0.9174, Validation Accuracy: 0.9148, Loss: 0.1350
# Epoch  53 Batch 1000/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.9048, Loss: 0.1384
# Epoch  53 Batch 1050/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9059, Loss: 0.1264
# Epoch  54 Batch   50/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9109, Loss: 0.1263
# Epoch  54 Batch  100/1077 - Train Accuracy: 0.9141, Validation Accuracy: 0.9293, Loss: 0.1370
# Epoch  54 Batch  150/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9197, Loss: 0.1268
# Epoch  54 Batch  200/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.9190, Loss: 0.1256
# Epoch  54 Batch  250/1077 - Train Accuracy: 0.9240, Validation Accuracy: 0.9116, Loss: 0.1067
# Epoch  54 Batch  300/1077 - Train Accuracy: 0.9712, Validation Accuracy: 0.9126, Loss: 0.1354
# Epoch  54 Batch  350/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9055, Loss: 0.1135
# Epoch  54 Batch  400/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.9105, Loss: 0.1520
# Epoch  54 Batch  450/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9002, Loss: 0.1419
# Epoch  54 Batch  500/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.9165, Loss: 0.1161
# Epoch  54 Batch  550/1077 - Train Accuracy: 0.8977, Validation Accuracy: 0.9162, Loss: 0.1237
# Epoch  54 Batch  600/1077 - Train Accuracy: 0.9435, Validation Accuracy: 0.9237, Loss: 0.1288
# Epoch  54 Batch  650/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9087, Loss: 0.1382
# Epoch  54 Batch  700/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9052, Loss: 0.1155
# Epoch  54 Batch  750/1077 - Train Accuracy: 0.9336, Validation Accuracy: 0.9134, Loss: 0.1444
# Epoch  54 Batch  800/1077 - Train Accuracy: 0.9410, Validation Accuracy: 0.9173, Loss: 0.1147
# Epoch  54 Batch  850/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.9123, Loss: 0.1504
# Epoch  54 Batch  900/1077 - Train Accuracy: 0.9305, Validation Accuracy: 0.9308, Loss: 0.1378
# Epoch  54 Batch  950/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9183, Loss: 0.1260
# Epoch  54 Batch 1000/1077 - Train Accuracy: 0.9170, Validation Accuracy: 0.9059, Loss: 0.1168
# Epoch  54 Batch 1050/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9261, Loss: 0.1222
# Epoch  55 Batch   50/1077 - Train Accuracy: 0.9437, Validation Accuracy: 0.8952, Loss: 0.1231
# Epoch  55 Batch  100/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.9240, Loss: 0.1295
# Epoch  55 Batch  150/1077 - Train Accuracy: 0.9144, Validation Accuracy: 0.9094, Loss: 0.1271
# Epoch  55 Batch  200/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.9173, Loss: 0.1242
# Epoch  55 Batch  250/1077 - Train Accuracy: 0.9276, Validation Accuracy: 0.9112, Loss: 0.1166
# Epoch  55 Batch  300/1077 - Train Accuracy: 0.9745, Validation Accuracy: 0.9215, Loss: 0.1128
# Epoch  55 Batch  350/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.8977, Loss: 0.1156
# Epoch  55 Batch  400/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9126, Loss: 0.1483
# Epoch  55 Batch  450/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.8991, Loss: 0.1305
# Epoch  55 Batch  500/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9084, Loss: 0.1044
# Epoch  55 Batch  550/1077 - Train Accuracy: 0.9117, Validation Accuracy: 0.9201, Loss: 0.1320
# Epoch  55 Batch  600/1077 - Train Accuracy: 0.9412, Validation Accuracy: 0.9041, Loss: 0.1189
# Epoch  55 Batch  650/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9144, Loss: 0.1355
# Epoch  55 Batch  700/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9027, Loss: 0.1010
# Epoch  55 Batch  750/1077 - Train Accuracy: 0.9336, Validation Accuracy: 0.9272, Loss: 0.1421
# Epoch  55 Batch  800/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9016, Loss: 0.1128
# Epoch  55 Batch  850/1077 - Train Accuracy: 0.9077, Validation Accuracy: 0.9137, Loss: 0.1563
# Epoch  55 Batch  900/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9237, Loss: 0.1365
# Epoch  55 Batch  950/1077 - Train Accuracy: 0.9275, Validation Accuracy: 0.9158, Loss: 0.1185
# Epoch  55 Batch 1000/1077 - Train Accuracy: 0.9167, Validation Accuracy: 0.9027, Loss: 0.1202
# Epoch  55 Batch 1050/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9183, Loss: 0.1066
# Epoch  56 Batch   50/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9080, Loss: 0.1192
# Epoch  56 Batch  100/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9283, Loss: 0.1312
# Epoch  56 Batch  150/1077 - Train Accuracy: 0.9029, Validation Accuracy: 0.9173, Loss: 0.1361
# Epoch  56 Batch  200/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9134, Loss: 0.1305
# Epoch  56 Batch  250/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9205, Loss: 0.1199
# Epoch  56 Batch  300/1077 - Train Accuracy: 0.9655, Validation Accuracy: 0.9059, Loss: 0.1179
# Epoch  56 Batch  350/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9222, Loss: 0.1136
# Epoch  56 Batch  400/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9300, Loss: 0.1480
# Epoch  56 Batch  450/1077 - Train Accuracy: 0.9469, Validation Accuracy: 0.9165, Loss: 0.1390
# Epoch  56 Batch  500/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9247, Loss: 0.1060
# Epoch  56 Batch  550/1077 - Train Accuracy: 0.9039, Validation Accuracy: 0.9190, Loss: 0.1302
# Epoch  56 Batch  600/1077 - Train Accuracy: 0.9368, Validation Accuracy: 0.9258, Loss: 0.1223
# Epoch  56 Batch  650/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9293, Loss: 0.1172
# Epoch  56 Batch  700/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9130, Loss: 0.1165
# Epoch  56 Batch  750/1077 - Train Accuracy: 0.9277, Validation Accuracy: 0.9300, Loss: 0.1233
# Epoch  56 Batch  800/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9219, Loss: 0.1136
# Epoch  56 Batch  850/1077 - Train Accuracy: 0.9092, Validation Accuracy: 0.9308, Loss: 0.1561
# Epoch  56 Batch  900/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9165, Loss: 0.1312
# Epoch  56 Batch  950/1077 - Train Accuracy: 0.9334, Validation Accuracy: 0.9219, Loss: 0.1235
# Epoch  56 Batch 1000/1077 - Train Accuracy: 0.9156, Validation Accuracy: 0.9112, Loss: 0.1236
# Epoch  56 Batch 1050/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9304, Loss: 0.1148
# Epoch  57 Batch   50/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9123, Loss: 0.1134
# Epoch  57 Batch  100/1077 - Train Accuracy: 0.9285, Validation Accuracy: 0.9329, Loss: 0.1210
# Epoch  57 Batch  150/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9130, Loss: 0.1200
# Epoch  57 Batch  200/1077 - Train Accuracy: 0.9227, Validation Accuracy: 0.9176, Loss: 0.1237
# Epoch  57 Batch  250/1077 - Train Accuracy: 0.9368, Validation Accuracy: 0.9219, Loss: 0.1083
# Epoch  57 Batch  300/1077 - Train Accuracy: 0.9671, Validation Accuracy: 0.9272, Loss: 0.1198
# Epoch  57 Batch  350/1077 - Train Accuracy: 0.9285, Validation Accuracy: 0.9070, Loss: 0.1100
# Epoch  57 Batch  400/1077 - Train Accuracy: 0.9262, Validation Accuracy: 0.9222, Loss: 0.1283
# Epoch  57 Batch  450/1077 - Train Accuracy: 0.9469, Validation Accuracy: 0.9055, Loss: 0.1176
# Epoch  57 Batch  500/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9183, Loss: 0.1077
# Epoch  57 Batch  550/1077 - Train Accuracy: 0.8980, Validation Accuracy: 0.9162, Loss: 0.1254
# Epoch  57 Batch  600/1077 - Train Accuracy: 0.9338, Validation Accuracy: 0.9055, Loss: 0.1085
# Epoch  57 Batch  650/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9066, Loss: 0.1258
# Epoch  57 Batch  700/1077 - Train Accuracy: 0.9672, Validation Accuracy: 0.9098, Loss: 0.1059
# Epoch  57 Batch  750/1077 - Train Accuracy: 0.9277, Validation Accuracy: 0.9222, Loss: 0.1327
# Epoch  57 Batch  800/1077 - Train Accuracy: 0.9469, Validation Accuracy: 0.9318, Loss: 0.1203
# Epoch  57 Batch  850/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.9222, Loss: 0.1506
# Epoch  57 Batch  900/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.9290, Loss: 0.1548
# Epoch  57 Batch  950/1077 - Train Accuracy: 0.9394, Validation Accuracy: 0.9205, Loss: 0.1335
# Epoch  57 Batch 1000/1077 - Train Accuracy: 0.9115, Validation Accuracy: 0.9244, Loss: 0.1104
# Epoch  57 Batch 1050/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9244, Loss: 0.1018
# Epoch  58 Batch   50/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9134, Loss: 0.1157
# Epoch  58 Batch  100/1077 - Train Accuracy: 0.9168, Validation Accuracy: 0.9322, Loss: 0.1331
# Epoch  58 Batch  150/1077 - Train Accuracy: 0.9286, Validation Accuracy: 0.9162, Loss: 0.1209
# Epoch  58 Batch  200/1077 - Train Accuracy: 0.9223, Validation Accuracy: 0.9119, Loss: 0.1289
# Epoch  58 Batch  250/1077 - Train Accuracy: 0.9382, Validation Accuracy: 0.9233, Loss: 0.1151
# Epoch  58 Batch  300/1077 - Train Accuracy: 0.9642, Validation Accuracy: 0.8991, Loss: 0.1155
# Epoch  58 Batch  350/1077 - Train Accuracy: 0.9313, Validation Accuracy: 0.9045, Loss: 0.0996
# Epoch  58 Batch  400/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.9212, Loss: 0.1328
# Epoch  58 Batch  450/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9169, Loss: 0.1267
# Epoch  58 Batch  500/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9208, Loss: 0.1064
# Epoch  58 Batch  550/1077 - Train Accuracy: 0.8980, Validation Accuracy: 0.9009, Loss: 0.1220
# Epoch  58 Batch  600/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9176, Loss: 0.1246
# Epoch  58 Batch  650/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9134, Loss: 0.1337
# Epoch  58 Batch  700/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9105, Loss: 0.1033
# Epoch  58 Batch  750/1077 - Train Accuracy: 0.9336, Validation Accuracy: 0.9141, Loss: 0.1239
# Epoch  58 Batch  800/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9151, Loss: 0.1061
# Epoch  58 Batch  850/1077 - Train Accuracy: 0.9174, Validation Accuracy: 0.9286, Loss: 0.1506
# Epoch  58 Batch  900/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9261, Loss: 0.1259
# Epoch  58 Batch  950/1077 - Train Accuracy: 0.9356, Validation Accuracy: 0.9165, Loss: 0.1202
# Epoch  58 Batch 1000/1077 - Train Accuracy: 0.9010, Validation Accuracy: 0.8991, Loss: 0.1147
# Epoch  58 Batch 1050/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9205, Loss: 0.1078
# Epoch  59 Batch   50/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9158, Loss: 0.1157
# Epoch  59 Batch  100/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.9261, Loss: 0.1102
# Epoch  59 Batch  150/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9134, Loss: 0.1194
# Epoch  59 Batch  200/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.9144, Loss: 0.1198
# Epoch  59 Batch  250/1077 - Train Accuracy: 0.9194, Validation Accuracy: 0.9329, Loss: 0.1181
# Epoch  59 Batch  300/1077 - Train Accuracy: 0.9696, Validation Accuracy: 0.9297, Loss: 0.1168
# Epoch  59 Batch  350/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9038, Loss: 0.1075
# Epoch  59 Batch  400/1077 - Train Accuracy: 0.9305, Validation Accuracy: 0.9205, Loss: 0.1449
# Epoch  59 Batch  450/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9077, Loss: 0.1260
# Epoch  59 Batch  500/1077 - Train Accuracy: 0.9227, Validation Accuracy: 0.9098, Loss: 0.0941
# Epoch  59 Batch  550/1077 - Train Accuracy: 0.8965, Validation Accuracy: 0.9183, Loss: 0.1284
# Epoch  59 Batch  600/1077 - Train Accuracy: 0.9524, Validation Accuracy: 0.9201, Loss: 0.1214
# Epoch  59 Batch  650/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9162, Loss: 0.1166
# Epoch  59 Batch  700/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9162, Loss: 0.1014
# Epoch  59 Batch  750/1077 - Train Accuracy: 0.9316, Validation Accuracy: 0.9222, Loss: 0.1203
# Epoch  59 Batch  800/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9197, Loss: 0.1104
# Epoch  59 Batch  850/1077 - Train Accuracy: 0.9107, Validation Accuracy: 0.9240, Loss: 0.1224
# Epoch  59 Batch  900/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9265, Loss: 0.1267
# Epoch  59 Batch  950/1077 - Train Accuracy: 0.9237, Validation Accuracy: 0.9134, Loss: 0.1132
# Epoch  59 Batch 1000/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.9201, Loss: 0.1145
# Epoch  59 Batch 1050/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9183, Loss: 0.1123
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    r = [vocab_to_int[w] if w in vocab_to_int else vocab_to_int['<UNK>'] for w in sentence.split()]
    return r


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input_data:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [26, 51, 81, 212, 109, 131, 116]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [287, 216, 14, 302, 305, 229, 203, 49, 1]
#   French Words: il a vu un vieux camion noir . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
